# %% [markdown]
# # Desafío tripulaciones (abr 22)
# ## Grupo 2. Asociación en Red
# ### Generamos las tablas necesarias para subir a MongoDB Compass-Atlas

# %%
#Importacion de librerias
import numpy as np
from faker import Factory
from faker import Faker
import random
import pandas as pd

# %% [markdown]
# ## Tabla Categorias

# %% [markdown]
# Categorías y descripciones trasladadas desde UX

# %%
categorias = pd.DataFrame({"Categorias" : ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día","Burocracia", "Servicios del Municipio"],
                "Descripcion": ["¿Necesitas asistencia con tu móvil, ordenador o televisión? Enviar un correo, hacer una videollamada, poner Netflix en la tele…","¿Quieres pedir cita médica por Internet o que alguien te acompañe?",
                "Entra aquí y conoce personas cercanas y afines a ti","¿Buscas compañía en tu rutina diaria o ayuda con las tareas cotidianas?",
                "¿No sabes cómo gestionar tu papeleo por Internet?", "Entérate y disfruta de todos los planes en tu zona"],
                "img": ["tecnologias.png", "salud.png", "amigos.png", "diaadia.png", "burocracia.png", "municipio.png"]})

categorias
# Out:
#                 Categorias                                        Descripcion  \
# 0       Nuevas Tecnologías  ¿Necesitas asistencia con tu móvil, ordenador ...
# 1                    Salud  ¿Quieres pedir cita médica por Internet o que ...
# 2            Amigos y Ocio  Entra aquí y conoce personas cercanas y afines...
# 3             El día a día  ¿Buscas compañía en tu rutina diaria o ayuda c...
# 4               Burocracia  ¿No sabes cómo gestionar tu papeleo por Internet?
# 5  Servicios del Municipio  Entérate y disfruta de todos los planes en tu ...
#
#                img
# 0  tecnologias.png
# 1        salud.png
# 2       amigos.png
# 3      diaadia.png
# 4   burocracia.png
# 5    municipio.png

# %%
categorias.to_csv('categorias.csv')

# %% [markdown]
# ## Codigo Postal

# %% [markdown]
# Descargamos desde https://github.com/inigoflores/ds-codigos-postales-ine-es la base de datos correspondientes a los
# códigos postales de España. Aplicamos las modificaciones correspondientes a caracteres no reconocidos.

# %%
df = pd.read_csv('utils/listado-de-codigos-postales-de-españa.csv', sep=';', encoding='latin-1')

# %%
df['poblacion'] = df['poblacion'].str.replace('?', 'ñ')
df.head(30)
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
#       provincia              poblacion  codigopostalid
# 0   Araba/Álava       Alegría-Dulantzi             240
# 1         Ávila              Candeleda             548
# 2   Araba/Álava        Vitoria-Gasteiz            1001
# 3   Araba/Álava        Vitoria-Gasteiz            1002
# 4   Araba/Álava        Vitoria-Gasteiz            1003
# 5   Araba/Álava        Vitoria-Gasteiz            1004
# 6   Araba/Álava        Vitoria-Gasteiz            1005
# 7   Araba/Álava        Vitoria-Gasteiz            1006
# 8   Araba/Álava        Vitoria-Gasteiz            1007
# 9   Araba/Álava        Vitoria-Gasteiz            1008
# 10  Araba/Álava        Vitoria-Gasteiz            1009
# 11  Araba/Álava        Vitoria-Gasteiz            1010
# 12  Araba/Álava        Vitoria-Gasteiz            1012
# 13  Araba/Álava      Labastida/Bastida            1012
# 14  Araba/Álava        Vitoria-Gasteiz            1013
# 15  Araba/Álava        Vitoria-Gasteiz            1015
# 16  Araba/Álava        Campezo/Kanpezu            1110
# 17  Araba/Álava        Campezo/Kanpezu            1117
# 18  Araba/Álava  Harana/Valle de Arana            1117
# 19       Burgos     Condado de Treviño            1118
# 20  Araba/Álava                Bernedo            1118
# 21  Araba/Álava                 Lagrán            1118
# 22  Araba/Álava          Arraia-Maeztu            1120
# 23  Araba/Álava        Campezo/Kanpezu            1128
# 24  Araba/Álava          Arraia-Maeztu            1128
# 25  Araba/Álava                Bernedo            1128
# 26  Araba/Álava          Arraia-Maeztu            1129
# 27  Araba/Álava                   Zuia            1130
# 28  Araba/Álava               Zigoitia            1138
# 29  Araba/Álava                   Zuia            1139

# %%
cpostal = df['codigopostalid']
cpostal
# Out:
# 0          240
# 1          548
# 2         1001
# 3         1002
# 4         1003
#          ...
# 14660    52004
# 14661    52005
# 14662    52006
# 14663    73820
# 14664    90007
# Name: codigopostalid, Length: 14665, dtype: int64

# %%
# Rellenamos con ceros a la izquierda los códigos postales con menos de 5 dígitos
ci = []
for i in cpostal:
    i=str(i)
    i = i.zfill(5)
    ci.append(i)

# %%
cp = pd.DataFrame(ci, columns=['cp'])
df['cp'] = cp
df.drop(columns='codigopostalid', inplace=True)
df.head(30)
# Out:
#       provincia              poblacion     cp
# 0   Araba/Álava       Alegría-Dulantzi  00240
# 1         Ávila              Candeleda  00548
# 2   Araba/Álava        Vitoria-Gasteiz  01001
# 3   Araba/Álava        Vitoria-Gasteiz  01002
# 4   Araba/Álava        Vitoria-Gasteiz  01003
# 5   Araba/Álava        Vitoria-Gasteiz  01004
# 6   Araba/Álava        Vitoria-Gasteiz  01005
# 7   Araba/Álava        Vitoria-Gasteiz  01006
# 8   Araba/Álava        Vitoria-Gasteiz  01007
# 9   Araba/Álava        Vitoria-Gasteiz  01008
# 10  Araba/Álava        Vitoria-Gasteiz  01009
# 11  Araba/Álava        Vitoria-Gasteiz  01010
# 12  Araba/Álava        Vitoria-Gasteiz  01012
# 13  Araba/Álava      Labastida/Bastida  01012
# 14  Araba/Álava        Vitoria-Gasteiz  01013
# 15  Araba/Álava        Vitoria-Gasteiz  01015
# 16  Araba/Álava        Campezo/Kanpezu  01110
# 17  Araba/Álava        Campezo/Kanpezu  01117
# 18  Araba/Álava  Harana/Valle de Arana  01117
# 19       Burgos     Condado de Treviño  01118
# 20  Araba/Álava                Bernedo  01118
# 21  Araba/Álava                 Lagrán  01118
# 22  Araba/Álava          Arraia-Maeztu  01120
# 23  Araba/Álava        Campezo/Kanpezu  01128
# 24  Araba/Álava          Arraia-Maeztu  01128
# 25  Araba/Álava                Bernedo  01128
# 26  Araba/Álava          Arraia-Maeztu  01129
# 27  Araba/Álava                   Zuia  01130
# 28  Araba/Álava               Zigoitia  01138
# 29  Araba/Álava                   Zuia  01139

# %%
cp = df.to_csv('codigo_postal.csv')

# %% [markdown]
# ## Tipos de perfiles

# %% [markdown]
# Creamos la tabla de perfiles con los datos trasladados desde UX

# %%
perfiles = pd.DataFrame({"perfil" : ["Miembros", "Voluntarios", "Ambos", "Admin"],
                "descripcion": ["Elige esta opción si buscas a alguien que te acompañe para solucionar tus problemas.", "Elige esta opción si buscas aportar tu granito de arena a la comunidad de mayores.", "Elige esta opción si buscas las dos opciones anteriores.", "Perfil administrador"],
                "img": ["miembros.png", "voluntarios.png", "ambos.png", " "]})
perfiles.to_csv('tipos_perfil.csv')

# %% [markdown]
# ## Tabla voluntarios (parte1)

# %%
voluntarios = {'nombre':[], 'apellidos':[]}
voluntarios
# Out:
# {'nombre': [], 'apellidos': []}

# %%
# Generamos nombre y apellidos ficticios con la librería faker

fake = Faker('es_ES')
fake.seed_instance(42)
for i in np.arange(0,500):
    name = fake.first_name()
    voluntarios['nombre'].append(name)
    apellido = fake.unique.last_name()
    voluntarios['apellidos'].append(apellido)

# %%
# Generamos aleatoriamente los números de teléfonos para completar este campo

tl = {'tl' : []}

for i in np.arange(0, 500):
    rand = random.randrange(600000000, 700000000)
    tl['tl'].append(rand)

tel = pd.DataFrame(tl)

# %%
# Elegimos un código postal aleatorio

cp = {'CP' : []}
for i in np.arange(0,500):
    rand = random.choice(df['cp'])
    cp['CP'].append(rand)

cp = pd.DataFrame(cp)

# %%
# Generamos contraseñas aleatorias para completar el campo pass

contr = {'pass': []}
for i in np.arange(0,500):
    rand = random.randrange(12345678, 87654321)
    contr['pass'].append(rand)

contr = pd.DataFrame(contr)

# %%
# Elegimos al azar los perfiles de Voluntario y Ambos

tipo_c = ['Voluntario', 'Ambos']
tipo = {'Tipo': []}
for i in np.arange(0,500):
    rand = random.choice(tipo_c)
    tipo['Tipo'].append(rand)

tipo = pd.DataFrame(tipo)

# %% [markdown]
# Creamos todas las combinaciones posibles de los servicios ofrecidos para introducirlas dentro de una lista.

# %%
servicios_c= [["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 	["Salud", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Burocracia"], 	["Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 	
["Nuevas Tecnologías", "Salud", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día"], 
["Nuevas Tecnologías", "El día a día", "Burocracia", "Servicios del Municipio"], 	
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Servicios del Municipio"],
["Salud", "Amigos y Ocio", "El día a día", "Burocracia"], ["Salud", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "El día a día", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Burocracia"],
["Salud", "Amigos y Ocio", "El día a día", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "El día a día", "Burocracia"],
["El día a día", "Burocracia", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio"],
["Salud", "El día a día", "Servicios del Municipio"], 	["Nuevas Tecnologías", "Amigos y Ocio", "Burocracia"], 
["Nuevas Tecnologías", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "Servicios del Municipio"], 
["Salud", "Amigos y Ocio", "Servicios del Municipio"], ["Nuevas Tecnologías", "Amigos y Ocio", "El día a día"], 
["Nuevas Tecnologías", "Salud", "El día a día"], ["Amigos y Ocio", "Burocracia", "Servicios del Municipio"], 
["Amigos y Ocio", "El día a día", "Servicios del Municipio"], ["Amigos y Ocio", "El día a día", "Burocracia"], 
["Nuevas Tecnologías", "El día a día", "Servicios del Municipio"],
["Nuevas Tecnologías", "El día a día", "Burocracia"], ["Salud", "Burocracia", "Servicios del Municipio"], ["Nuevas Tecnologías", "Amigos y Ocio", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud"], ["Nuevas Tecnologías", "Amigos y Ocio"],
["Nuevas Tecnologías", "El día a día"], ["Nuevas Tecnologías", "Burocracia"], 
["Nuevas Tecnologías", "Servicios del Municipio"], ["Salud", "Amigos y Ocio"], 
["Salud", "El día a día"], 	["Salud", "Burocracia"], ["Salud", "Servicios del Municipio"],
["Amigos y Ocio", "El día a día"], 	["Amigos y Ocio", "Burocracia"], 
["Amigos y Ocio", "Servicios del Municipio"], ["El día a día", "Burocracia"], 
["El día a día", "Servicios del Municipio"], ["Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías"], ["Salud"], 	["Amigos y Ocio"],
   ["El día a día"], ["Burocracia"], ["Servicios del Municipio"]]


servicios = {'Servicios disponibles': []}
for i in np.arange(0,500):
    rand = random.choice(servicios_c)
    servicios['Servicios disponibles'].append(rand)

servicios = pd.DataFrame(servicios)

# %%
# Creamos aleatorio el status de los voluntarios (0 = no disponible, 1 =  disponible)
s = [0, 1]
status={'Status': []}
for i in np.arange(0,500):
    rand = random.choice(s)
    status['Status'].append(rand)

status = pd.DataFrame(status)

# %% [markdown]
# Imagenes descargadas de figma y renombradas para utilizar aleatoriamente en las tablas de voluntarios y miembros

# %%
imagenes = ["hombre1.png","hombre2.png","miembroh1.png","miembroh3.png","miembrom3.png","miembrom4.png",
"mujer1.png","mujer2.png","opinion1.png","opinion2m.png","opinion3m.png","opinion4.png","opinion5m.png",
"opinion6.png"]

# %%
# Introducimos aleatoriamente las fotografías para cada uno de los voluntarios

img_vol = ["hombre1.png","mujer1.png", "hombre2.png","mujer2.png"]
img_v={'Foto vol': []}
for i in np.arange(0,500):
    rand = random.choice(img_vol)
    img_v['Foto vol'].append(rand)

img_v = pd.DataFrame(img_v)

# %% [markdown]
# Se generar mini biografías para el perfil de los voluntarios

# %%
bio1 = "Soy una persona muy atenta. Me gusta aportar mi granito de arena siempre que puedo. Estaría encantada de poder acompañarte en lo que necesites."
bio2 = "Me encanta sertirme útil y por eso estaría encantada de poder ayudarte."
bio3 = "Me gusta trabajar con otras personas, codo con codo, sumando fuerzas, compartiendo experiencias y aprendiendo unas de otras, creciendo juntos."
bio4 = "Soy una persona a la que le fascina conocer personas diferentes y aprender de los demas para conseguir un objetivo común."
bio5 = "Me gusta pasar mi tiempo ayudando a los demás y hacer nuevos amigos."
bio6 = "Quiero devolver a la comunidad lo que me dieron sin pedir nada a cambio."

# %%
bios = [bio1, bio2, bio3, bio4, bio5, bio6]
bio = {'Bio': []}
for i in np.arange(0,500):
    rand = random.choice(bios)
    bio['Bio'].append(rand)

bio = pd.DataFrame(bio)

# %% [markdown]
# Para generar fechas aleatorias entre rangos utilizamos la función del siguiente recurso:
#
# https://es.stackoverflow.com/questions/418863/como-generar-una-fecha-aleatoria-entre-dos-rangos-con-random-randit-en-python

# %%
from random import randint
from datetime import datetime


DATE_FORMAT = '%d/%m/%Y'


def get_random_date_between(date_a, date_b):    
    datetime_object_a = datetime.strptime(date_a, DATE_FORMAT)
    datetime_object_b = datetime.strptime(date_b, DATE_FORMAT)

    random_ordinal = randint(
        datetime_object_a.toordinal(),
        datetime_object_b.toordinal(),
    )

    random_date = datetime.fromordinal(random_ordinal)
    formatted_date_string = random_date.strftime(DATE_FORMAT)

    return formatted_date_string

get_random_date_between('17/5/2019', '30/6/2022')
# Out:
# '03/08/2019'

# %%
# Generamos fechas aleatorias de registro de voluntarios

f_insc = {'Fecha inscripcion': []}
for i in np.arange(0,500):
    rand = get_random_date_between('17/5/2019', '30/6/2022')
    f_insc['Fecha inscripcion'].append(rand)

inscripcion = pd.DataFrame(f_insc)

# %%
# unificamos en un único DataFrame todos los campos creados anteriormente

voluntarios = pd.DataFrame(voluntarios)
voluntarios['movil'] = tel
voluntarios['codigoPostal'] = cp
voluntarios['pass'] = contr
voluntarios['perfil'] = tipo
voluntarios['serviciosDisponibles'] = servicios
voluntarios['status'] = status
voluntarios['fotoV'] = img_v
voluntarios['bio'] = bio
voluntarios['fechaInscripcion'] = inscripcion
voluntarios.head(5)
# Out:
#          nombre  apellidos      movil codigoPostal      pass      perfil  \
# 0     Feliciana     Cantón  694747145        40331  44349840  Voluntario
# 1        Amador     Llopis  607054985        44587  23964109  Voluntario
# 2  Jose Ignacio      Godoy  682114060        22612  81577056  Voluntario
# 3        Emilio  Calatayud  640282913        37800  30558301  Voluntario
# 4    Inmaculada      Bonet  640233560        40215  16325875  Voluntario
#
#                                 serviciosDisponibles  status        fotoV  \
# 0  [Nuevas Tecnologías, Burocracia, Servicios del...       1  hombre2.png
# 1     [Nuevas Tecnologías, El día a día, Burocracia]       1   mujer1.png
# 2  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...       1   mujer1.png
# 3  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...       1  hombre2.png
# 4  [Amigos y Ocio, El día a día, Burocracia, Serv...       1   mujer2.png
#
#                                                  bio fechaInscripcion
# 0  Soy una persona muy atenta. Me gusta aportar m...       19/11/2019
# 1  Me gusta trabajar con otras personas, codo con...       28/05/2020
# 2  Me gusta trabajar con otras personas, codo con...       10/02/2020
# 3  Soy una persona muy atenta. Me gusta aportar m...       02/09/2020
# 4  Me gusta trabajar con otras personas, codo con...       19/03/2020

# %%
# Unimos los campos Nombre y Apellidos

voluntarios.insert(2, 'nombreApellidos', voluntarios[['nombre', 'apellidos']].apply(' '.join, axis=1))
voluntarios.head(2)
# Out:
#       nombre apellidos   nombreApellidos      movil codigoPostal      pass  \
# 0  Feliciana    Cantón  Feliciana Cantón  694747145        40331  44349840
# 1     Amador    Llopis     Amador Llopis  607054985        44587  23964109
#
#        perfil                               serviciosDisponibles  status  \
# 0  Voluntario  [Nuevas Tecnologías, Burocracia, Servicios del...       1
# 1  Voluntario     [Nuevas Tecnologías, El día a día, Burocracia]       1
#
#          fotoV                                                bio  \
# 0  hombre2.png  Soy una persona muy atenta. Me gusta aportar m...
# 1   mujer1.png  Me gusta trabajar con otras personas, codo con...
#
#   fechaInscripcion
# 0       19/11/2019
# 1       28/05/2020

# %% [markdown]
# ## Miembros

# %% [markdown]
# Creamos la base de datos con los campos de los miembros.
# Añadimos las imágenes distintas de voluntarios para esta tabla.

# %%
miembros = {'nombre':[], 'apellidos':[], 'movil': [], 'codigoPostal': [], 'pass': [], 'fotoMiembro' : [], 'fechaInscripcion' : []}

# %%
img_m = ["miembroh1.png","miembroh3.png","miembrom3.png","miembrom4.png", "opinion1.png","opinion2m.png",
"opinion3m.png","opinion4.png","opinion5m.png","opinion6.png"]

# %%
# Generamos aleatoriamente los campos de nombre, apellidos, móvil, código postal, pass, imagen y fecha de inscripción

fake = Faker('es_ES')
fake.seed_instance(100)
for i in np.arange(0,1000):
    name = fake.first_name()
    miembros['nombre'].append(name)
    apellido = fake.unique.last_name()
    miembros['apellidos'].append(apellido)
    rand = random.randrange(600000000, 700000000)
    miembros['movil'].append(rand)
    postal = random.choice(df['cp'])
    miembros['codigoPostal'].append(postal)
    cont = random.randrange(12345678, 87654321)
    miembros['pass'].append(cont)
    img = random.choice(img_m)
    miembros['fotoMiembro'].append(img)
    fecha = get_random_date_between('17/5/2019', '30/6/2022')
    miembros['fechaInscripcion'].append(fecha)

miembros = pd.DataFrame(miembros)
miembros.head(30)
# Out:
#        nombre  apellidos      movil codigoPostal      pass    fotoMiembro  \
# 0     Esteban     Segura  604666433        22336  15931002  miembroh3.png
# 1      Wálter       Díaz  692146083        41339  48704007  miembroh3.png
# 2     Julieta       Pozo  670338882        24224  35134451  opinion3m.png
# 3      Lupita       Olmo  601176618        46369  35883850  opinion3m.png
# 4     Toribio   Vendrell  699110621        41849  39633634   opinion1.png
# 5     Nereida      Canet  676025998        09248  29583274  opinion2m.png
# 6       Berta    Carrión  651838152        34874  19444040  miembrom4.png
# 7     Cecilio  Sarmiento  637952259        15830  25129193   opinion4.png
# 8   Juan José    Asensio  634033376        46450  41984558  miembrom4.png
# 9    Genoveva     Fuente  641957795        48419  78837977  opinion5m.png
# 10       Nico       Gras  632197964        08779  50041982   opinion6.png
# 11     Martin      Frías  641509246        07430  53869679  miembrom4.png
# 12     Gaspar      Chico  622618789        01128  60524737  miembrom4.png
# 13    Gonzalo     Oliver  675164743        04660  67182469  miembrom3.png
# 14     Rafael    Redondo  630804951        33836  82739885  miembroh1.png
# 15    Perlita     Galvez  694045616        37799  24442020  opinion5m.png
# 16     Samuel      Serra  638016195        17470  65810923   opinion1.png
# 17   Catalina    Llorens  610847681        03679  66725122  miembrom4.png
# 18  Valentina      Perez  690675688        17154  23813693  opinion5m.png
# 19     Felipe   Casanova  639627359        17245  65281182  opinion5m.png
# 20    Geraldo       Adán  698716728        34487  70008004  miembrom4.png
# 21      Elisa     Priego  668106211        35423  13228183  miembroh1.png
# 22    Eusebio     Cámara  602649136        31487  81575411   opinion1.png
# 23  Guadalupe      Diego  675829354        20159  40481732  opinion2m.png
# 24  Prudencia        Amo  630131737        49630  69656911  opinion2m.png
# 25    Xiomara     Gálvez  694781177        26121  63254365   opinion1.png
# 26  Victorino      Ponce  617099161        45140  19306488   opinion1.png
# 27    Edmundo      Badía  604458363        14199  55906062  miembroh1.png
# 28    Emelina    Huertas  617509323        34002  81667816  miembroh1.png
# 29    Liliana     Manjón  613559154        47492  56559626  miembrom4.png
#
#    fechaInscripcion
# 0        16/05/2022
# 1        21/04/2022
# 2        05/07/2020
# 3        08/03/2021
# 4        26/11/2020
# 5        27/02/2020
# 6        17/12/2021
# 7        12/09/2021
# 8        18/06/2019
# 9        31/03/2020
# 10       05/10/2019
# 11       27/10/2020
# 12       29/06/2020
# 13       05/06/2022
# 14       31/05/2022
# 15       09/05/2020
# 16       09/08/2019
# 17       11/06/2020
# 18       12/08/2021
# 19       24/09/2020
# 20       21/04/2020
# 21       17/04/2022
# 22       24/08/2020
# 23       24/06/2021
# 24       23/12/2020
# 25       28/11/2019
# 26       27/12/2020
# 27       25/07/2021
# 28       06/07/2021
# 29       08/03/2021

# %%
# Unificamos la columna Nombre y Apellidos

miembros.insert(2, 'nombreApellidos', miembros[['nombre', 'apellidos']].apply(' '.join, axis=1))
miembros.head(2)
# Out:
#     nombre apellidos nombreApellidos      movil codigoPostal      pass  \
# 0  Esteban    Segura  Esteban Segura  604666433        22336  15931002
# 1   Wálter      Díaz     Wálter Díaz  692146083        41339  48704007
#
#      fotoMiembro fechaInscripcion
# 0  miembroh3.png       16/05/2022
# 1  miembroh3.png       21/04/2022

# %%
# Filtramos los usuarios con perfil "Ambos" de la tabla de voluntarios para poder añadirlos a la tabla de Miembros

masm = voluntarios[voluntarios['perfil'] == 'Ambos']
masm
# Out:
#         nombre apellidos     nombreApellidos      movil codigoPostal  \
# 5      Dominga      Roca        Dominga Roca  699473870        32720
# 9       Eligia      Amor         Eligia Amor  657614171        29010
# 10       Chelo      Flor          Chelo Flor  619887239        36677
# 13     Dolores      Lobo        Dolores Lobo  644603054        14511
# 14       Nydia     Agudo         Nydia Agudo  649984050        39880
# ..         ...       ...                 ...        ...          ...
# 487  Estefanía  Hernando  Estefanía Hernando  616121666        16854
# 491      Ángel      Jara          Ángel Jara  698623988        02139
# 493  Valentina  Benavent  Valentina Benavent  609047636        38670
# 498  Heliodoro    Planas    Heliodoro Planas  698636536        15528
# 499      Reyna     Tomas         Reyna Tomas  667774464        16555
#
#          pass perfil                               serviciosDisponibles  \
# 5    52032135  Ambos  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 9    77216346  Ambos  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 10   35587026  Ambos  [Nuevas Tecnologías, El día a día, Burocracia,...
# 13   50796682  Ambos                              [Salud, El día a día]
# 14   30835715  Ambos                              [Salud, El día a día]
# ..        ...    ...                                                ...
# 487  74852812  Ambos  [Nuevas Tecnologías, Salud, Servicios del Muni...
# 491  64503573  Ambos  [Nuevas Tecnologías, El día a día, Burocracia,...
# 493  27421256  Ambos  [Amigos y Ocio, El día a día, Burocracia, Serv...
# 498  29517950  Ambos      [Nuevas Tecnologías, Servicios del Municipio]
# 499  72730980  Ambos              [Burocracia, Servicios del Municipio]
#
#      status        fotoV                                                bio  \
# 5         0  hombre1.png  Me gusta trabajar con otras personas, codo con...
# 9         0  hombre2.png  Me encanta sertirme útil y por eso estaría enc...
# 10        0   mujer1.png  Me gusta pasar mi tiempo ayudando a los demás ...
# 13        0   mujer2.png  Me encanta sertirme útil y por eso estaría enc...
# 14        0   mujer1.png  Me encanta sertirme útil y por eso estaría enc...
# ..      ...          ...                                                ...
# 487       0   mujer1.png  Me gusta pasar mi tiempo ayudando a los demás ...
# 491       1   mujer1.png  Quiero devolver a la comunidad lo que me diero...
# 493       0  hombre2.png  Soy una persona a la que le fascina conocer pe...
# 498       1   mujer1.png  Me encanta sertirme útil y por eso estaría enc...
# 499       1   mujer2.png  Me gusta pasar mi tiempo ayudando a los demás ...
#
#     fechaInscripcion
# 5         14/02/2022
# 9         01/07/2019
# 10        09/06/2019
# 13        08/08/2021
# 14        29/11/2020
# ..               ...
# 487       26/05/2021
# 491       24/11/2019
# 493       06/01/2022
# 498       07/12/2020
# 499       26/04/2022
#
# [240 rows x 12 columns]

# %%
# Del filtro realizado, eliminamos las columnas que no corresponden a la categoría "Miembro"
miembro = masm.drop(columns=['perfil', 'serviciosDisponibles', 'status', 'bio'])
miembro
# Out:
#         nombre apellidos     nombreApellidos      movil codigoPostal  \
# 5      Dominga      Roca        Dominga Roca  699473870        32720
# 9       Eligia      Amor         Eligia Amor  657614171        29010
# 10       Chelo      Flor          Chelo Flor  619887239        36677
# 13     Dolores      Lobo        Dolores Lobo  644603054        14511
# 14       Nydia     Agudo         Nydia Agudo  649984050        39880
# ..         ...       ...                 ...        ...          ...
# 487  Estefanía  Hernando  Estefanía Hernando  616121666        16854
# 491      Ángel      Jara          Ángel Jara  698623988        02139
# 493  Valentina  Benavent  Valentina Benavent  609047636        38670
# 498  Heliodoro    Planas    Heliodoro Planas  698636536        15528
# 499      Reyna     Tomas         Reyna Tomas  667774464        16555
#
#          pass        fotoV fechaInscripcion
# 5    52032135  hombre1.png       14/02/2022
# 9    77216346  hombre2.png       01/07/2019
# 10   35587026   mujer1.png       09/06/2019
# 13   50796682   mujer2.png       08/08/2021
# 14   30835715   mujer1.png       29/11/2020
# ..        ...          ...              ...
# 487  74852812   mujer1.png       26/05/2021
# 491  64503573   mujer1.png       24/11/2019
# 493  27421256  hombre2.png       06/01/2022
# 498  29517950   mujer1.png       07/12/2020
# 499  72730980   mujer2.png       26/04/2022
#
# [240 rows x 8 columns]

# %%
# Renombramos las columnas para que correspondan a las mismas que la tabla Miembros

miembro.columns= ['nombre', 'apellidos', 'nombreApellidos', 'movil', 'codigoPostal', 'pass',
       'fotoMiembro', 'fechaInscripcion']
miembro
# Out:
#         nombre apellidos     nombreApellidos      movil codigoPostal  \
# 5      Dominga      Roca        Dominga Roca  699473870        32720
# 9       Eligia      Amor         Eligia Amor  657614171        29010
# 10       Chelo      Flor          Chelo Flor  619887239        36677
# 13     Dolores      Lobo        Dolores Lobo  644603054        14511
# 14       Nydia     Agudo         Nydia Agudo  649984050        39880
# ..         ...       ...                 ...        ...          ...
# 487  Estefanía  Hernando  Estefanía Hernando  616121666        16854
# 491      Ángel      Jara          Ángel Jara  698623988        02139
# 493  Valentina  Benavent  Valentina Benavent  609047636        38670
# 498  Heliodoro    Planas    Heliodoro Planas  698636536        15528
# 499      Reyna     Tomas         Reyna Tomas  667774464        16555
#
#          pass  fotoMiembro fechaInscripcion
# 5    52032135  hombre1.png       14/02/2022
# 9    77216346  hombre2.png       01/07/2019
# 10   35587026   mujer1.png       09/06/2019
# 13   50796682   mujer2.png       08/08/2021
# 14   30835715   mujer1.png       29/11/2020
# ..        ...          ...              ...
# 487  74852812   mujer1.png       26/05/2021
# 491  64503573   mujer1.png       24/11/2019
# 493  27421256  hombre2.png       06/01/2022
# 498  29517950   mujer1.png       07/12/2020
# 499  72730980   mujer2.png       26/04/2022
#
# [240 rows x 8 columns]

# %%
# Apilamos la nueva tabla filtrada desde voluntarios a la ya existente de Miembros

miembrosf = pd.concat([miembros, miembro], axis=0)
miembrosf.reset_index(inplace=True)
miembrosf.drop(columns=['index'],inplace=True)
miembrosf
# Out:
#          nombre apellidos     nombreApellidos      movil codigoPostal  \
# 0       Esteban    Segura      Esteban Segura  604666433        22336
# 1        Wálter      Díaz         Wálter Díaz  692146083        41339
# 2       Julieta      Pozo        Julieta Pozo  670338882        24224
# 3        Lupita      Olmo         Lupita Olmo  601176618        46369
# 4       Toribio  Vendrell    Toribio Vendrell  699110621        41849
# ...         ...       ...                 ...        ...          ...
# 1235  Estefanía  Hernando  Estefanía Hernando  616121666        16854
# 1236      Ángel      Jara          Ángel Jara  698623988        02139
# 1237  Valentina  Benavent  Valentina Benavent  609047636        38670
# 1238  Heliodoro    Planas    Heliodoro Planas  698636536        15528
# 1239      Reyna     Tomas         Reyna Tomas  667774464        16555
#
#           pass    fotoMiembro fechaInscripcion
# 0     15931002  miembroh3.png       16/05/2022
# 1     48704007  miembroh3.png       21/04/2022
# 2     35134451  opinion3m.png       05/07/2020
# 3     35883850  opinion3m.png       08/03/2021
# 4     39633634   opinion1.png       26/11/2020
# ...        ...            ...              ...
# 1235  74852812     mujer1.png       26/05/2021
# 1236  64503573     mujer1.png       24/11/2019
# 1237  27421256    hombre2.png       06/01/2022
# 1238  29517950     mujer1.png       07/12/2020
# 1239  72730980     mujer2.png       26/04/2022
#
# [1240 rows x 8 columns]

# %%
miembrosf.to_csv('miembros.csv')

# %% [markdown]
# ## Opiniones

# %% [markdown]
# Para realizar la tabla de opiniones se necesita a los voluntarios con sus áreas, además de los miembros que han realizado dicha reseña, puntuación y la reseña.

# %%
# Nos quedamos con los voluntarios y sus áreas de actuación

opiniones = voluntarios.iloc[:,2:8:5]
opiniones
# Out:
#         nombreApellidos                               serviciosDisponibles
# 0      Feliciana Cantón  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1         Amador Llopis     [Nuevas Tecnologías, El día a día, Burocracia]
# 2    Jose Ignacio Godoy  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3      Emilio Calatayud  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4      Inmaculada Bonet  [Amigos y Ocio, El día a día, Burocracia, Serv...
# ..                  ...                                                ...
# 495      Diana Martínez  [Nuevas Tecnologías, Salud, Amigos y Ocio, Ser...
# 496   Feliciana Rodrigo  [Amigos y Ocio, El día a día, Servicios del Mu...
# 497         Jenny Matas  [Nuevas Tecnologías, Burocracia, Servicios del...
# 498    Heliodoro Planas      [Nuevas Tecnologías, Servicios del Municipio]
# 499         Reyna Tomas              [Burocracia, Servicios del Municipio]
#
# [500 rows x 2 columns]

# %%
# Para generar más opiniones, cogemos un rango intermedio de la tabla anterior para apilarla.

res2 = opiniones.iloc[125:340, :2]
res2.reset_index(inplace=True)
res2.drop(columns=['index'],inplace=True)
res2
# Out:
#        nombreApellidos                               serviciosDisponibles
# 0     Jose Ramón Feliu  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 1        Goyo Sanabria  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 2      Enrique Español  [Nuevas Tecnologías, Burocracia, Servicios del...
# 3       León Sevillano  [Nuevas Tecnologías, Salud, El día a día, Buro...
# 4          Josep Benet                                     [El día a día]
# ..                 ...                                                ...
# 210      Gabriel Vélez                        [Amigos y Ocio, Burocracia]
# 211       Florina León  [Nuevas Tecnologías, Salud, El día a día, Serv...
# 212  Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 213        Adela Ruano  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 214      Paola Ledesma  [Nuevas Tecnologías, Salud, El día a día, Buro...
#
# [215 rows x 2 columns]

# %%
# Unificamos las dos tablas

resenas = pd.concat([opiniones, res2], axis=0)
resenas.reset_index(inplace=True)
resenas.drop(columns=['index'],inplace=True)
resenas
# Out:
#         nombreApellidos                               serviciosDisponibles
# 0      Feliciana Cantón  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1         Amador Llopis     [Nuevas Tecnologías, El día a día, Burocracia]
# 2    Jose Ignacio Godoy  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3      Emilio Calatayud  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4      Inmaculada Bonet  [Amigos y Ocio, El día a día, Burocracia, Serv...
# ..                  ...                                                ...
# 710       Gabriel Vélez                        [Amigos y Ocio, Burocracia]
# 711        Florina León  [Nuevas Tecnologías, Salud, El día a día, Serv...
# 712   Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 713         Adela Ruano  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 714       Paola Ledesma  [Nuevas Tecnologías, Salud, El día a día, Buro...
#
# [715 rows x 2 columns]

# %%
# Aleatoriamente asignamos una calificación a cada uno de los registros creados

estrellas = [1,2,3,4,5]
resena = {'Estrellas':[]}

for i in np.arange(0,715):
    clas = random.choice(estrellas)
    resena['Estrellas'].append(clas)

resena = pd.DataFrame(resena)
resenas['estrellas'] = resena
resenas.head()
# Out:
#       nombreApellidos                               serviciosDisponibles  \
# 0    Feliciana Cantón  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1       Amador Llopis     [Nuevas Tecnologías, El día a día, Burocracia]
# 2  Jose Ignacio Godoy  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3    Emilio Calatayud  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4    Inmaculada Bonet  [Amigos y Ocio, El día a día, Burocracia, Serv...
#
#    estrellas
# 0          5
# 1          2
# 2          3
# 3          5
# 4          1

# %% [markdown]
# Creamos distintos textos de opiniones para asignar en función de la puntuación registrada

# %%
op1 = ["Al final tuvo que irse antes", "El día podría haber estado mejor", "Llegó tarde", "No es muy habladora",
"No habla mucho", "No me arregló los papeles", "No me ayudó nada", "No me entendía", "No me pudo acompañar donde yo quería",
"No pudo ayudarme", "No sabía lo que le pedía", "Tuvo muy poca paciencia"]
op2 = ["Bueno, podría mejorar", "El servicio no estuvo mal", "Es amable aunque no divertida",
"Está normal", "Ha llegado tarde", "No ha ido mal", "No ha podido ayudarme en lo que necesitaba", 
"No sabía lo que le pedía", "No terminó de ayudarme", "Puede mejorar"]
op3 = ["Bien", "Es muy amable", "Estoy contenta", "Gracias", "Gran dia", "Ha estado bien", "Ha estado muy bien",
"Ha podido ayudarme en algunas cosas", "Me acompañó en lo que necesitaba", "Me ayudó en lo que necesitaba",
"Me ayudó mucho en casa", "Me ha ayudado en lo que le he pedido", "Me ha ayudado mucho", "Me ha resuelto muchas dudas",
"Me lo he pasado bien", "No hemos terminado de congeniar pero ha estado bien", "Un día agradable"]
op4 = ["Es un encanto y me ayudó a hablar con mis nietos", "Es un sol, me ayudó a desbloquear el móvil y lo arregló",
"Fue un día estupendo", "No hubiera podido está más feliz", "No puedo estar más agradecida"]
op5 = ["Encantado con toda la ayuda que he recibido", "Es un encanto y me ayudó a hablar con mis nietos",
"Es un sol, me ayudó a desbloquear el móvil y lo arregló", "Fue un día estupendo", "Gracias, ha sido toda una experiencia",
"Me ayudó mucho en casa", "No hubiera podido estar más feliz", "No puedo estar más agradecida",
"Qué bien que pudo ayudarme con mis papeles", "Sin duda seguiré utilizando este servicio"]

# %%
# En función de la puntuación asignada se elige un comentario aleatorio de los posibles.

op = {'Opinión' : []}
for i in np.arange(0, 715):
    if resenas['estrellas'][i] == 1:
        op_1 = random.choice(op1)
        op['Opinión'].append(op_1)
    elif resenas['estrellas'][i] == 2:
        op_2 = random.choice(op2)
        op['Opinión'].append(op_2)
    elif resenas['estrellas'][i] == 3:
        op_3 = random.choice(op3)
        op['Opinión'].append(op_3)
    elif resenas['estrellas'][i] == 4:
        op_4 = random.choice(op4)
        op['Opinión'].append(op_4)
    elif resenas['estrellas'][i] == 5:
        op_5 = random.choice(op5)
        op['Opinión'].append(op_5)

opi = pd.DataFrame(op)
resenas['opinion'] = opi
resenas.head()
# Out:
#       nombreApellidos                               serviciosDisponibles  \
# 0    Feliciana Cantón  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1       Amador Llopis     [Nuevas Tecnologías, El día a día, Burocracia]
# 2  Jose Ignacio Godoy  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3    Emilio Calatayud  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4    Inmaculada Bonet  [Amigos y Ocio, El día a día, Burocracia, Serv...
#
#    estrellas                                      opinion
# 0          5    Sin duda seguiré utilizando este servicio
# 1          2                        Bueno, podría mejorar
# 2          3                       Me ayudó mucho en casa
# 3          5  Encantado con toda la ayuda que he recibido
# 4          1                               No me entendía

# %%
# De la tabla de miembros final elegimos un rango intermedio que añadiremos al Dataframe de reseñas

miemb = miembrosf.iloc[303:1018,2::4]
miemb.reset_index(inplace=True)
miemb.drop(columns=['index'], inplace=True)
miemb
# Out:
#           nombreApellidos    fotoMiembro
# 0              Morena Pol   opinion1.png
# 1             Chelo Rojas   opinion4.png
# 2              Alma Luque  miembrom3.png
# 3         Ascensión Anaya  opinion2m.png
# 4           Leire Quiroga  opinion5m.png
# ..                    ...            ...
# 710  María Teresa Mancebo     mujer1.png
# 711      Cebrián Guerrero     mujer1.png
# 712        Roxana Cabrero     mujer2.png
# 713       Ricardo Santana    hombre2.png
# 714        Fabiola Patiño     mujer2.png
#
# [715 rows x 2 columns]

# %%
opinions = pd.concat([resenas, miemb], axis=1, ignore_index=True)
opinions.columns = ['nombreVoluntario', 'serviciosDisponibles', 'estrellas', 'opinion', 'nombreMiembro', 'fotoMiembro']
opinions
# Out:
#        nombreVoluntario                               serviciosDisponibles  \
# 0      Feliciana Cantón  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1         Amador Llopis     [Nuevas Tecnologías, El día a día, Burocracia]
# 2    Jose Ignacio Godoy  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3      Emilio Calatayud  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4      Inmaculada Bonet  [Amigos y Ocio, El día a día, Burocracia, Serv...
# ..                  ...                                                ...
# 710       Gabriel Vélez                        [Amigos y Ocio, Burocracia]
# 711        Florina León  [Nuevas Tecnologías, Salud, El día a día, Serv...
# 712   Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 713         Adela Ruano  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 714       Paola Ledesma  [Nuevas Tecnologías, Salud, El día a día, Buro...
#
#      estrellas                                      opinion  \
# 0            5    Sin duda seguiré utilizando este servicio
# 1            2                        Bueno, podría mejorar
# 2            3                       Me ayudó mucho en casa
# 3            5  Encantado con toda la ayuda que he recibido
# 4            1                               No me entendía
# ..         ...                                          ...
# 710          2                     No sabía lo que le pedía
# 711          3                           Ha estado muy bien
# 712          4                No puedo estar más agradecida
# 713          1                             No me ayudó nada
# 714          1                    No me arregló los papeles
#
#             nombreMiembro    fotoMiembro
# 0              Morena Pol   opinion1.png
# 1             Chelo Rojas   opinion4.png
# 2              Alma Luque  miembrom3.png
# 3         Ascensión Anaya  opinion2m.png
# 4           Leire Quiroga  opinion5m.png
# ..                    ...            ...
# 710  María Teresa Mancebo     mujer1.png
# 711      Cebrián Guerrero     mujer1.png
# 712        Roxana Cabrero     mujer2.png
# 713       Ricardo Santana    hombre2.png
# 714        Fabiola Patiño     mujer2.png
#
# [715 rows x 6 columns]

# %%
opinions.to_csv('opiniones.csv')

# %%
opcion = opinions.T
opcion
# Out:
#                                                                     0    \
# nombreVoluntario                                       Feliciana Cantón
# serviciosDisponibles  [Nuevas Tecnologías, Burocracia, Servicios del...
# estrellas                                                             5
# opinion                       Sin duda seguiré utilizando este servicio
# nombreMiembro                                                Morena Pol
# fotoMiembro                                                opinion1.png
#
#                                                                  1    \
# nombreVoluntario                                       Amador Llopis
# serviciosDisponibles  [Nuevas Tecnologías, El día a día, Burocracia]
# estrellas                                                          2
# opinion                                        Bueno, podría mejorar
# nombreMiembro                                            Chelo Rojas
# fotoMiembro                                             opinion4.png
#
#                                                                     2    \
# nombreVoluntario                                     Jose Ignacio Godoy
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# estrellas                                                             3
# opinion                                          Me ayudó mucho en casa
# nombreMiembro                                                Alma Luque
# fotoMiembro                                               miembrom3.png
#
#                                                                     3    \
# nombreVoluntario                                       Emilio Calatayud
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# estrellas                                                             5
# opinion                     Encantado con toda la ayuda que he recibido
# nombreMiembro                                           Ascensión Anaya
# fotoMiembro                                               opinion2m.png
#
#                                                                     4    \
# nombreVoluntario                                       Inmaculada Bonet
# serviciosDisponibles  [Amigos y Ocio, El día a día, Burocracia, Serv...
# estrellas                                                             1
# opinion                                                  No me entendía
# nombreMiembro                                             Leire Quiroga
# fotoMiembro                                               opinion5m.png
#
#                                                                     5    \
# nombreVoluntario                                           Dominga Roca
# serviciosDisponibles  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# estrellas                                                             1
# opinion                                       No me arregló los papeles
# nombreMiembro                                                 Luisa Cid
# fotoMiembro                                               opinion3m.png
#
#                                                                    6    \
# nombreVoluntario                                        Amílcar Andrés
# serviciosDisponibles               [Nuevas Tecnologías, Amigos y Ocio]
# estrellas                                                            5
# opinion               Es un encanto y me ayudó a hablar con mis nietos
# nombreMiembro                                             Nando Lloret
# fotoMiembro                                              opinion3m.png
#
#                                                                  7    \
# nombreVoluntario                                            Ciro Gil
# serviciosDisponibles  [Salud, El día a día, Servicios del Municipio]
# estrellas                                                          2
# opinion                                    El servicio no estuvo mal
# nombreMiembro                                            Paco Perera
# fotoMiembro                                            opinion3m.png
#
#                                                                     8    \
# nombreVoluntario                                           Joan Vazquez
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Servicios del Muni...
# estrellas                                                             3
# opinion               No hemos terminado de congeniar pero ha estado...
# nombreMiembro                                          Teodosio Carrera
# fotoMiembro                                                opinion6.png
#
#                                                                     9    ...  \
# nombreVoluntario                                            Eligia Amor  ...
# serviciosDisponibles  [Nuevas Tecnologías, Amigos y Ocio, El día a d...  ...
# estrellas                                                             2  ...
# opinion                                          No terminó de ayudarme  ...
# nombreMiembro                                               Cruz España  ...
# fotoMiembro                                                opinion1.png  ...
#
#                                                                     705  \
# nombreVoluntario                                         Flora Nogueira
# serviciosDisponibles  [Nuevas Tecnologías, Salud, El día a día, Serv...
# estrellas                                                             3
# opinion                            Me ha ayudado en lo que le he pedido
# nombreMiembro                                              Luna Segovia
# fotoMiembro                                                  mujer2.png
#
#                                                                     706  \
# nombreVoluntario                                          Albano Trillo
# serviciosDisponibles      [Nuevas Tecnologías, Servicios del Municipio]
# estrellas                                                             3
# opinion               No hemos terminado de congeniar pero ha estado...
# nombreMiembro                                              Ágata Pinedo
# fotoMiembro                                                  mujer1.png
#
#                                                                    707  \
# nombreVoluntario                                        Curro Rosselló
# serviciosDisponibles                                      [Burocracia]
# estrellas                                                            5
# opinion               Es un encanto y me ayudó a hablar con mis nietos
# nombreMiembro                                              Paula Pardo
# fotoMiembro                                                hombre1.png
#
#                                               708                   709  \
# nombreVoluntario                  Porfirio Segura           Laura Rozas
# serviciosDisponibles  [Amigos y Ocio, Burocracia]   [Salud, Burocracia]
# estrellas                                       1                     3
# opinion                 No me arregló los papeles  Me lo he pasado bien
# nombreMiembro                         Julie Baños          Artemio Goñi
# fotoMiembro                           hombre2.png            mujer1.png
#
#                                               710  \
# nombreVoluntario                    Gabriel Vélez
# serviciosDisponibles  [Amigos y Ocio, Burocracia]
# estrellas                                       2
# opinion                  No sabía lo que le pedía
# nombreMiembro                María Teresa Mancebo
# fotoMiembro                            mujer1.png
#
#                                                                     711  \
# nombreVoluntario                                           Florina León
# serviciosDisponibles  [Nuevas Tecnologías, Salud, El día a día, Serv...
# estrellas                                                             3
# opinion                                              Ha estado muy bien
# nombreMiembro                                          Cebrián Guerrero
# fotoMiembro                                                  mujer1.png
#
#                                                                     712  \
# nombreVoluntario                                      Encarnación Tomás
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# estrellas                                                             4
# opinion                                   No puedo estar más agradecida
# nombreMiembro                                            Roxana Cabrero
# fotoMiembro                                                  mujer2.png
#
#                                                                     713  \
# nombreVoluntario                                            Adela Ruano
# serviciosDisponibles  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# estrellas                                                             1
# opinion                                                No me ayudó nada
# nombreMiembro                                           Ricardo Santana
# fotoMiembro                                                 hombre2.png
#
#                                                                     714
# nombreVoluntario                                          Paola Ledesma
# serviciosDisponibles  [Nuevas Tecnologías, Salud, El día a día, Buro...
# estrellas                                                             1
# opinion                                       No me arregló los papeles
# nombreMiembro                                            Fabiola Patiño
# fotoMiembro                                                  mujer2.png
#
# [6 rows x 715 columns]

# %%
opcion.to_json('opcion.json')

# %%
opinions.to_json('opiniones_json.json')

# %% [markdown]
# ## Voluntarios (parte2)

# %% [markdown]
# En la tabla de voluntarios añadiremos una columna con la media de las puntuaciones indicadas en la tabla de opiniones
# y otra columna con el número de opiniones de cada uno de los voluntarios

# %%
star = pd.Series(opinions.groupby(['nombreVoluntario']).estrellas.mean().round(1), name='estrellas')
count = pd.Series(opinions.groupby(['nombreVoluntario']).opinion.count(), name='nOpinion')
df3 = pd.DataFrame([star, count])

# %%
df3 = df3.T
df3.reset_index(inplace=True)

df3
# Out:
#     nombreVoluntario  estrellas  nOpinion
# 0       Abril Ibañez        2.0       2.0
# 1         Adela Jaén        3.0       2.0
# 2        Adela Ruano        3.0       2.0
# 3    Adela Salamanca        2.5       2.0
# 4       Adelina Vall        2.0       1.0
# ..               ...        ...       ...
# 495     Ángeles Sanz        4.0       2.0
# 496    Áurea Maestre        4.0       1.0
# 497     Íñigo Carpio        3.0       1.0
# 498  Úrsula Belmonte        1.5       2.0
# 499     Úrsula Perez        3.0       2.0
#
# [500 rows x 3 columns]

# %%
df3['nOpinion'] = df3['nOpinion'].astype('int64', errors='ignore')

# %%
# Unimos la tabla generada con la media de las puntuaciones y el número de opiniones a la tabla de voluntarios

voluntariosf= pd.merge(left= voluntarios, right= df3, how = 'outer', left_on=voluntarios['nombreApellidos'], 
                        right_on=df3['nombreVoluntario'])

voluntariosf
# Out:
#                   key_0        nombre  apellidos     nombreApellidos  \
# 0      Feliciana Cantón     Feliciana     Cantón    Feliciana Cantón
# 1         Amador Llopis        Amador     Llopis       Amador Llopis
# 2    Jose Ignacio Godoy  Jose Ignacio      Godoy  Jose Ignacio Godoy
# 3      Emilio Calatayud        Emilio  Calatayud    Emilio Calatayud
# 4      Inmaculada Bonet    Inmaculada      Bonet    Inmaculada Bonet
# ..                  ...           ...        ...                 ...
# 495      Diana Martínez         Diana   Martínez      Diana Martínez
# 496   Feliciana Rodrigo     Feliciana    Rodrigo   Feliciana Rodrigo
# 497         Jenny Matas         Jenny      Matas         Jenny Matas
# 498    Heliodoro Planas     Heliodoro     Planas    Heliodoro Planas
# 499         Reyna Tomas         Reyna      Tomas         Reyna Tomas
#
#          movil codigoPostal      pass      perfil  \
# 0    694747145        40331  44349840  Voluntario
# 1    607054985        44587  23964109  Voluntario
# 2    682114060        22612  81577056  Voluntario
# 3    640282913        37800  30558301  Voluntario
# 4    640233560        40215  16325875  Voluntario
# ..         ...          ...       ...         ...
# 495  698908720        49121  17626065  Voluntario
# 496  684551502        29620  34923397  Voluntario
# 497  618955625        50326  49108853  Voluntario
# 498  698636536        15528  29517950       Ambos
# 499  667774464        16555  72730980       Ambos
#
#                                   serviciosDisponibles  status        fotoV  \
# 0    [Nuevas Tecnologías, Burocracia, Servicios del...       1  hombre2.png
# 1       [Nuevas Tecnologías, El día a día, Burocracia]       1   mujer1.png
# 2    [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...       1   mujer1.png
# 3    [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...       1  hombre2.png
# 4    [Amigos y Ocio, El día a día, Burocracia, Serv...       1   mujer2.png
# ..                                                 ...     ...          ...
# 495  [Nuevas Tecnologías, Salud, Amigos y Ocio, Ser...       1   mujer1.png
# 496  [Amigos y Ocio, El día a día, Servicios del Mu...       1   mujer2.png
# 497  [Nuevas Tecnologías, Burocracia, Servicios del...       0   mujer2.png
# 498      [Nuevas Tecnologías, Servicios del Municipio]       1   mujer1.png
# 499              [Burocracia, Servicios del Municipio]       1   mujer2.png
#
#                                                    bio fechaInscripcion  \
# 0    Soy una persona muy atenta. Me gusta aportar m...       19/11/2019
# 1    Me gusta trabajar con otras personas, codo con...       28/05/2020
# 2    Me gusta trabajar con otras personas, codo con...       10/02/2020
# 3    Soy una persona muy atenta. Me gusta aportar m...       02/09/2020
# 4    Me gusta trabajar con otras personas, codo con...       19/03/2020
# ..                                                 ...              ...
# 495  Me encanta sertirme útil y por eso estaría enc...       15/12/2019
# 496  Me gusta pasar mi tiempo ayudando a los demás ...       15/01/2022
# 497  Me gusta pasar mi tiempo ayudando a los demás ...       27/06/2022
# 498  Me encanta sertirme útil y por eso estaría enc...       07/12/2020
# 499  Me gusta pasar mi tiempo ayudando a los demás ...       26/04/2022
#
#        nombreVoluntario  estrellas  nOpinion
# 0      Feliciana Cantón        5.0         1
# 1         Amador Llopis        2.0         1
# 2    Jose Ignacio Godoy        3.0         1
# 3      Emilio Calatayud        5.0         1
# 4      Inmaculada Bonet        1.0         1
# ..                  ...        ...       ...
# 495      Diana Martínez        4.0         1
# 496   Feliciana Rodrigo        1.0         1
# 497         Jenny Matas        2.0         1
# 498    Heliodoro Planas        3.0         1
# 499         Reyna Tomas        2.0         1
#
# [500 rows x 16 columns]

# %%
# Eliminamos las columnas que se han creado automáticamente con la unión de los dataframes

voluntariosf.drop(columns=["key_0", "nombreVoluntario"], inplace=True)
voluntariosf.head()
# Out:
#          nombre  apellidos     nombreApellidos      movil codigoPostal  \
# 0     Feliciana     Cantón    Feliciana Cantón  694747145        40331
# 1        Amador     Llopis       Amador Llopis  607054985        44587
# 2  Jose Ignacio      Godoy  Jose Ignacio Godoy  682114060        22612
# 3        Emilio  Calatayud    Emilio Calatayud  640282913        37800
# 4    Inmaculada      Bonet    Inmaculada Bonet  640233560        40215
#
#        pass      perfil                               serviciosDisponibles  \
# 0  44349840  Voluntario  [Nuevas Tecnologías, Burocracia, Servicios del...
# 1  23964109  Voluntario     [Nuevas Tecnologías, El día a día, Burocracia]
# 2  81577056  Voluntario  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 3  30558301  Voluntario  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 4  16325875  Voluntario  [Amigos y Ocio, El día a día, Burocracia, Serv...
#
#    status        fotoV                                                bio  \
# 0       1  hombre2.png  Soy una persona muy atenta. Me gusta aportar m...
# 1       1   mujer1.png  Me gusta trabajar con otras personas, codo con...
# 2       1   mujer1.png  Me gusta trabajar con otras personas, codo con...
# 3       1  hombre2.png  Soy una persona muy atenta. Me gusta aportar m...
# 4       1   mujer2.png  Me gusta trabajar con otras personas, codo con...
#
#   fechaInscripcion  estrellas  nOpinion
# 0       19/11/2019        5.0         1
# 1       28/05/2020        2.0         1
# 2       10/02/2020        3.0         1
# 3       02/09/2020        5.0         1
# 4       19/03/2020        1.0         1

# %%
voluntariosf.to_csv('voluntarios.csv')

# %%
voluntariosf.to_json('voluntarios_json.json')

# %%
volunt = voluntariosf.T
volunt
# Out:
#                                                                     0    \
# nombre                                                        Feliciana
# apellidos                                                        Cantón
# nombreApellidos                                        Feliciana Cantón
# movil                                                         694747145
# codigoPostal                                                      40331
# pass                                                           44349840
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Burocracia, Servicios del...
# status                                                                1
# fotoV                                                       hombre2.png
# bio                   Soy una persona muy atenta. Me gusta aportar m...
# fechaInscripcion                                             19/11/2019
# estrellas                                                           5.0
# nOpinion                                                              1
#
#                                                                     1    \
# nombre                                                           Amador
# apellidos                                                        Llopis
# nombreApellidos                                           Amador Llopis
# movil                                                         607054985
# codigoPostal                                                      44587
# pass                                                           23964109
# perfil                                                       Voluntario
# serviciosDisponibles     [Nuevas Tecnologías, El día a día, Burocracia]
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Me gusta trabajar con otras personas, codo con...
# fechaInscripcion                                             28/05/2020
# estrellas                                                           2.0
# nOpinion                                                              1
#
#                                                                     2    \
# nombre                                                     Jose Ignacio
# apellidos                                                         Godoy
# nombreApellidos                                      Jose Ignacio Godoy
# movil                                                         682114060
# codigoPostal                                                      22612
# pass                                                           81577056
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Me gusta trabajar con otras personas, codo con...
# fechaInscripcion                                             10/02/2020
# estrellas                                                           3.0
# nOpinion                                                              1
#
#                                                                     3    \
# nombre                                                           Emilio
# apellidos                                                     Calatayud
# nombreApellidos                                        Emilio Calatayud
# movil                                                         640282913
# codigoPostal                                                      37800
# pass                                                           30558301
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# status                                                                1
# fotoV                                                       hombre2.png
# bio                   Soy una persona muy atenta. Me gusta aportar m...
# fechaInscripcion                                             02/09/2020
# estrellas                                                           5.0
# nOpinion                                                              1
#
#                                                                     4    \
# nombre                                                       Inmaculada
# apellidos                                                         Bonet
# nombreApellidos                                        Inmaculada Bonet
# movil                                                         640233560
# codigoPostal                                                      40215
# pass                                                           16325875
# perfil                                                       Voluntario
# serviciosDisponibles  [Amigos y Ocio, El día a día, Burocracia, Serv...
# status                                                                1
# fotoV                                                        mujer2.png
# bio                   Me gusta trabajar con otras personas, codo con...
# fechaInscripcion                                             19/03/2020
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     5    \
# nombre                                                          Dominga
# apellidos                                                          Roca
# nombreApellidos                                            Dominga Roca
# movil                                                         699473870
# codigoPostal                                                      32720
# pass                                                           52032135
# perfil                                                            Ambos
# serviciosDisponibles  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# status                                                                0
# fotoV                                                       hombre1.png
# bio                   Me gusta trabajar con otras personas, codo con...
# fechaInscripcion                                             14/02/2022
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     6    \
# nombre                                                          Amílcar
# apellidos                                                        Andrés
# nombreApellidos                                          Amílcar Andrés
# movil                                                         685229691
# codigoPostal                                                      48901
# pass                                                           43682168
# perfil                                                       Voluntario
# serviciosDisponibles                [Nuevas Tecnologías, Amigos y Ocio]
# status                                                                0
# fotoV                                                       hombre1.png
# bio                   Quiero devolver a la comunidad lo que me diero...
# fechaInscripcion                                             22/05/2020
# estrellas                                                           5.0
# nOpinion                                                              1
#
#                                                                     7    \
# nombre                                                             Ciro
# apellidos                                                           Gil
# nombreApellidos                                                Ciro Gil
# movil                                                         690660156
# codigoPostal                                                      17469
# pass                                                           72701581
# perfil                                                       Voluntario
# serviciosDisponibles     [Salud, El día a día, Servicios del Municipio]
# status                                                                1
# fotoV                                                        mujer2.png
# bio                   Me gusta trabajar con otras personas, codo con...
# fechaInscripcion                                             06/12/2021
# estrellas                                                           2.0
# nOpinion                                                              1
#
#                                                                     8    \
# nombre                                                             Joan
# apellidos                                                       Vazquez
# nombreApellidos                                            Joan Vazquez
# movil                                                         638142941
# codigoPostal                                                      25192
# pass                                                           69344357
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Servicios del Muni...
# status                                                                0
# fotoV                                                       hombre1.png
# bio                   Soy una persona a la que le fascina conocer pe...
# fechaInscripcion                                             01/03/2021
# estrellas                                                           3.0
# nOpinion                                                              1
#
#                                                                     9    ...  \
# nombre                                                           Eligia  ...
# apellidos                                                          Amor  ...
# nombreApellidos                                             Eligia Amor  ...
# movil                                                         657614171  ...
# codigoPostal                                                      29010  ...
# pass                                                           77216346  ...
# perfil                                                            Ambos  ...
# serviciosDisponibles  [Nuevas Tecnologías, Amigos y Ocio, El día a d...  ...
# status                                                                0  ...
# fotoV                                                       hombre2.png  ...
# bio                   Me encanta sertirme útil y por eso estaría enc...  ...
# fechaInscripcion                                             01/07/2019  ...
# estrellas                                                           2.0  ...
# nOpinion                                                              1  ...
#
#                                                                     490  \
# nombre                                                          Felicia
# apellidos                                                     Izquierdo
# nombreApellidos                                       Felicia Izquierdo
# movil                                                         671766794
# codigoPostal                                                      19190
# pass                                                           26233080
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Burocracia, Servicios del...
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Soy una persona a la que le fascina conocer pe...
# fechaInscripcion                                             06/02/2021
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     491  \
# nombre                                                            Ángel
# apellidos                                                          Jara
# nombreApellidos                                              Ángel Jara
# movil                                                         698623988
# codigoPostal                                                      02139
# pass                                                           64503573
# perfil                                                            Ambos
# serviciosDisponibles  [Nuevas Tecnologías, El día a día, Burocracia,...
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Quiero devolver a la comunidad lo que me diero...
# fechaInscripcion                                             24/11/2019
# estrellas                                                           5.0
# nOpinion                                                              1
#
#                                                                     492  \
# nombre                                                         Griselda
# apellidos                                                          Sola
# nombreApellidos                                           Griselda Sola
# movil                                                         612908215
# codigoPostal                                                      30204
# pass                                                           85264533
# perfil                                                       Voluntario
# serviciosDisponibles                                       [Burocracia]
# status                                                                1
# fotoV                                                        mujer2.png
# bio                   Me encanta sertirme útil y por eso estaría enc...
# fechaInscripcion                                             22/01/2021
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     493  \
# nombre                                                        Valentina
# apellidos                                                      Benavent
# nombreApellidos                                      Valentina Benavent
# movil                                                         609047636
# codigoPostal                                                      38670
# pass                                                           27421256
# perfil                                                            Ambos
# serviciosDisponibles  [Amigos y Ocio, El día a día, Burocracia, Serv...
# status                                                                0
# fotoV                                                       hombre2.png
# bio                   Soy una persona a la que le fascina conocer pe...
# fechaInscripcion                                             06/01/2022
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     494  \
# nombre                                                            Vasco
# apellidos                                                         Ojeda
# nombreApellidos                                             Vasco Ojeda
# movil                                                         658364784
# codigoPostal                                                      20270
# pass                                                           51422804
# perfil                                                       Voluntario
# serviciosDisponibles           [Amigos y Ocio, Servicios del Municipio]
# status                                                                0
# fotoV                                                       hombre1.png
# bio                   Me gusta pasar mi tiempo ayudando a los demás ...
# fechaInscripcion                                             28/01/2020
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     495  \
# nombre                                                            Diana
# apellidos                                                      Martínez
# nombreApellidos                                          Diana Martínez
# movil                                                         698908720
# codigoPostal                                                      49121
# pass                                                           17626065
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Salud, Amigos y Ocio, Ser...
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Me encanta sertirme útil y por eso estaría enc...
# fechaInscripcion                                             15/12/2019
# estrellas                                                           4.0
# nOpinion                                                              1
#
#                                                                     496  \
# nombre                                                        Feliciana
# apellidos                                                       Rodrigo
# nombreApellidos                                       Feliciana Rodrigo
# movil                                                         684551502
# codigoPostal                                                      29620
# pass                                                           34923397
# perfil                                                       Voluntario
# serviciosDisponibles  [Amigos y Ocio, El día a día, Servicios del Mu...
# status                                                                1
# fotoV                                                        mujer2.png
# bio                   Me gusta pasar mi tiempo ayudando a los demás ...
# fechaInscripcion                                             15/01/2022
# estrellas                                                           1.0
# nOpinion                                                              1
#
#                                                                     497  \
# nombre                                                            Jenny
# apellidos                                                         Matas
# nombreApellidos                                             Jenny Matas
# movil                                                         618955625
# codigoPostal                                                      50326
# pass                                                           49108853
# perfil                                                       Voluntario
# serviciosDisponibles  [Nuevas Tecnologías, Burocracia, Servicios del...
# status                                                                0
# fotoV                                                        mujer2.png
# bio                   Me gusta pasar mi tiempo ayudando a los demás ...
# fechaInscripcion                                             27/06/2022
# estrellas                                                           2.0
# nOpinion                                                              1
#
#                                                                     498  \
# nombre                                                        Heliodoro
# apellidos                                                        Planas
# nombreApellidos                                        Heliodoro Planas
# movil                                                         698636536
# codigoPostal                                                      15528
# pass                                                           29517950
# perfil                                                            Ambos
# serviciosDisponibles      [Nuevas Tecnologías, Servicios del Municipio]
# status                                                                1
# fotoV                                                        mujer1.png
# bio                   Me encanta sertirme útil y por eso estaría enc...
# fechaInscripcion                                             07/12/2020
# estrellas                                                           3.0
# nOpinion                                                              1
#
#                                                                     499
# nombre                                                            Reyna
# apellidos                                                         Tomas
# nombreApellidos                                             Reyna Tomas
# movil                                                         667774464
# codigoPostal                                                      16555
# pass                                                           72730980
# perfil                                                            Ambos
# serviciosDisponibles              [Burocracia, Servicios del Municipio]
# status                                                                1
# fotoV                                                        mujer2.png
# bio                   Me gusta pasar mi tiempo ayudando a los demás ...
# fechaInscripcion                                             26/04/2022
# estrellas                                                           2.0
# nOpinion                                                              1
#
# [14 rows x 500 columns]

# %%
volunt.to_json('voluntarios.json')

# %% [markdown]
# ## Peticiones

# %% [markdown]
# La tabla de peticiones va a contener el asunto de las solicitudes generadas por los usuarios y el texto completo.
# Además, se va a incluir el número de kms y una fecha de creación de solicitud aleatoriamente.
#
# Creamos los asuntos y textos a partir de lo trasladado por el área de UX.

# %%
p1 = 'Me gustaría saber mandar un correo'
p2 = 'Llamar a mis nietos por el ordenador'
p3 = 'Quiero poner música en mi móvil'
p4 = 'Que no se pone el banco en el teléfono'
p5 = 'Quiero poner dibujos en el chat como mi vecina'
p6 = 'No sé qué móvil comprarme'



t1 = 'El otro día recibí un mensaje y no sé cómo responderlo por ordenador'
t2 = 'Quiero ver a mis nietos por el ordenador'
t3 = 'Me gusta un grupo de música nuevo y quiero tenerlo en el móvil'
t4 = 'Quiero consultar mi cuenta del banco por el móvil'
t5 = 'He visto que mi vecina está poniendo muñecos en el chat y también quiero'
t6 = 'Se me ha roto el móvil y quiero saber cuál comprarme'

peticiones= {p1:t1, p2:t2, p3:t3, p4:t4, p5:t5, p6:t6}

# %%
# Para crear esta tabla utilizamos un rago intermedio de la tabla de miembros.

peticionarios = miembros.iloc[171:211, 2:7:4]
peticionarios.reset_index(inplace=True)
peticionarios.drop(columns=['index'], inplace=True)
peticionarios
# Out:
#           nombreApellidos    fotoMiembro
# 0           Adrián Blanco   opinion1.png
# 1       Anastasia Barrera   opinion1.png
# 2         Teodoro Pizarro   opinion6.png
# 3         Fabián Ferreras  miembrom3.png
# 4       Tristán Escribano  miembrom3.png
# 5      Hernando Larrañaga   opinion1.png
# 6      José Luis Gelabert  miembrom4.png
# 7             Lázaro Páez   opinion1.png
# 8             Valeria Pou  miembroh3.png
# 9    Juan Bautista Múgica   opinion1.png
# 10           Amaro Larrea   opinion6.png
# 11  Jose Angel Echeverría  opinion5m.png
# 12       Baldomero Ricart  miembroh1.png
# 13         Ciro Carretero  opinion5m.png
# 14     Fortunato Pellicer  opinion2m.png
# 15          Iker Villegas  opinion3m.png
# 16      Jorge Quintanilla  opinion5m.png
# 17          Alfredo Soler  miembroh1.png
# 18             Pili Navas   opinion4.png
# 19           Aníbal Landa  miembrom3.png
# 20       Andrea Benavente  miembrom3.png
# 21          Pelayo Arnaiz  miembroh1.png
# 22         Gabriela Jordá  opinion2m.png
# 23             Maura Seco   opinion4.png
# 24             Coral Malo  miembrom4.png
# 25           Bibiana Puga   opinion6.png
# 26       Prudencio Morata  miembroh1.png
# 27           Fausto Cases   opinion1.png
# 28           Malena Nieto  opinion5m.png
# 29             Ana Pulido  miembroh3.png
# 30         Esmeralda Real  miembrom3.png
# 31     Jose Manuel Valera   opinion4.png
# 32     Marcela Cabanillas  miembroh3.png
# 33        Bernarda Galván  miembroh3.png
# 34        Gabriel Benítez  miembroh3.png
# 35     Jose Luis Berrocal  opinion3m.png
# 36           Alejo Losada  miembroh3.png
# 37         Perlita Tolosa  miembroh1.png
# 38        Isidoro Naranjo  miembrom4.png
# 39          Santos Arroyo   opinion1.png

# %%
# Generamos aleatoriamente el asunto y el texto del mismo.

asunto = {'asunto': [], 'texto': []}

for i in np.arange(0,40):
    pt = random.choice(list(peticiones.items()))
    asunto['asunto'].append(pt[0])
    asunto['texto'].append(pt[1])

asunto = pd.DataFrame(asunto)

asunto.head()
# Out:
#                                            asunto  \
# 0              Me gustaría saber mandar un correo
# 1  Quiero poner dibujos en el chat como mi vecina
# 2                 Quiero poner música en mi móvil
# 3            Llamar a mis nietos por el ordenador
# 4                       No sé qué móvil comprarme
#
#                                                texto
# 0  El otro día recibí un mensaje y no sé cómo res...
# 1  He visto que mi vecina está poniendo muñecos e...
# 2  Me gusta un grupo de música nuevo y quiero ten...
# 3           Quiero ver a mis nietos por el ordenador
# 4  Se me ha roto el móvil y quiero saber cuál com...

# %%
# Unimos esta nueva tabla a la principal

solicitudes = pd.concat([peticionarios, asunto], axis=1)
solicitudes.head()
# Out:
#      nombreApellidos    fotoMiembro  \
# 0      Adrián Blanco   opinion1.png
# 1  Anastasia Barrera   opinion1.png
# 2    Teodoro Pizarro   opinion6.png
# 3    Fabián Ferreras  miembrom3.png
# 4  Tristán Escribano  miembrom3.png
#
#                                            asunto  \
# 0              Me gustaría saber mandar un correo
# 1  Quiero poner dibujos en el chat como mi vecina
# 2                 Quiero poner música en mi móvil
# 3            Llamar a mis nietos por el ordenador
# 4                       No sé qué móvil comprarme
#
#                                                texto
# 0  El otro día recibí un mensaje y no sé cómo res...
# 1  He visto que mi vecina está poniendo muñecos e...
# 2  Me gusta un grupo de música nuevo y quiero ten...
# 3           Quiero ver a mis nietos por el ordenador
# 4  Se me ha roto el móvil y quiero saber cuál com...

# %%
# Generamos el rango de fechas aleatorio

creacion = {'Fecha creacion': []}

for i in np.arange(0,40):
    fech = get_random_date_between('17/6/2022', '30/7/2022')
    creacion['Fecha creacion'].append(fech)

creacion = pd.DataFrame(creacion)
solicitudes['fechaCreacion'] = creacion
solicitudes.head()
# Out:
#      nombreApellidos    fotoMiembro  \
# 0      Adrián Blanco   opinion1.png
# 1  Anastasia Barrera   opinion1.png
# 2    Teodoro Pizarro   opinion6.png
# 3    Fabián Ferreras  miembrom3.png
# 4  Tristán Escribano  miembrom3.png
#
#                                            asunto  \
# 0              Me gustaría saber mandar un correo
# 1  Quiero poner dibujos en el chat como mi vecina
# 2                 Quiero poner música en mi móvil
# 3            Llamar a mis nietos por el ordenador
# 4                       No sé qué móvil comprarme
#
#                                                texto fechaCreacion
# 0  El otro día recibí un mensaje y no sé cómo res...    05/07/2022
# 1  He visto que mi vecina está poniendo muñecos e...    04/07/2022
# 2  Me gusta un grupo de música nuevo y quiero ten...    22/06/2022
# 3           Quiero ver a mis nietos por el ordenador    05/07/2022
# 4  Se me ha roto el móvil y quiero saber cuál com...    14/07/2022

# %%
# Elegimos el rango de kms de forma aleatoria

kms = {'Kms': []}

for i in np.arange(0,40):
    km = random.randrange(5, 40)
    kms['Kms'].append(str(km)+'km')

kms = pd.DataFrame(kms)
solicitudes['Kms'] = kms
solicitudes.head()
# Out:
#      nombreApellidos    fotoMiembro  \
# 0      Adrián Blanco   opinion1.png
# 1  Anastasia Barrera   opinion1.png
# 2    Teodoro Pizarro   opinion6.png
# 3    Fabián Ferreras  miembrom3.png
# 4  Tristán Escribano  miembrom3.png
#
#                                            asunto  \
# 0              Me gustaría saber mandar un correo
# 1  Quiero poner dibujos en el chat como mi vecina
# 2                 Quiero poner música en mi móvil
# 3            Llamar a mis nietos por el ordenador
# 4                       No sé qué móvil comprarme
#
#                                                texto fechaCreacion   Kms
# 0  El otro día recibí un mensaje y no sé cómo res...    05/07/2022  37km
# 1  He visto que mi vecina está poniendo muñecos e...    04/07/2022  38km
# 2  Me gusta un grupo de música nuevo y quiero ten...    22/06/2022  36km
# 3           Quiero ver a mis nietos por el ordenador    05/07/2022  10km
# 4  Se me ha roto el móvil y quiero saber cuál com...    14/07/2022  19km

# %%
solicitudes.to_csv('solicitudes.csv')
