# %% [markdown]
# # Desafío tripulaciones (abr 22)
# ## Grupo 2. Asociación en Red
# ### Generamos las tablas necesarias para subir a MongoDB Compass-Atlas

# %%
#Importacion de librerias
import numpy as np
from faker import Factory
from faker import Faker
import random
import pandas as pd

# %% [markdown]
# ## Tabla Categorias

# %% [markdown]
# Categorías y descripciones trasladadas desde UX

# %%
categorias = pd.DataFrame({"Categorias" : ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día","Burocracia", "Servicios del Municipio"],
                "Descripcion": ["¿Necesitas asistencia con tu móvil, ordenador o televisión? Enviar un correo, hacer una videollamada, poner Netflix en la tele…","¿Quieres pedir cita médica por Internet o que alguien te acompañe?",
                "Entra aquí y conoce personas cercanas y afines a ti","¿Buscas compañía en tu rutina diaria o ayuda con las tareas cotidianas?",
                "¿No sabes cómo gestionar tu papeleo por Internet?", "Entérate y disfruta de todos los planes en tu zona"],
                "img": ["tecnologias.png", "salud.png", "amigos.png", "diaadia.png", "burocracia.png", "municipio.png"]})

categorias
# Out:
#                 Categorias                                        Descripcion  \
# 0       Nuevas Tecnologías  ¿Necesitas asistencia con tu móvil, ordenador ...
# 1                    Salud  ¿Quieres pedir cita médica por Internet o que ...
# 2            Amigos y Ocio  Entra aquí y conoce personas cercanas y afines...
# 3             El día a día  ¿Buscas compañía en tu rutina diaria o ayuda c...
# 4               Burocracia  ¿No sabes cómo gestionar tu papeleo por Internet?
# 5  Servicios del Municipio  Entérate y disfruta de todos los planes en tu ...
#
#                img
# 0  tecnologias.png
# 1        salud.png
# 2       amigos.png
# 3      diaadia.png
# 4   burocracia.png
# 5    municipio.png

# %%
categorias.to_csv('categorias.csv')

# %% [markdown]
# ## Codigo Postal

# %% [markdown]
# Descargamos desde https://github.com/inigoflores/ds-codigos-postales-ine-es la base de datos correspondientes a los
# códigos postales de España. Aplicamos las modificaciones correspondientes a caracteres no reconocidos.

# %%
df = pd.read_csv('listado-de-codigos-postales-de-españa.csv', sep=';', encoding='latin-1')

# %%
df['poblacion'] = df['poblacion'].str.replace('?', 'ñ')
df.head(30)
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
#       provincia              poblacion  codigopostalid
# 0   Araba/Álava       Alegría-Dulantzi             240
# 1         Ávila              Candeleda             548
# 2   Araba/Álava        Vitoria-Gasteiz            1001
# 3   Araba/Álava        Vitoria-Gasteiz            1002
# 4   Araba/Álava        Vitoria-Gasteiz            1003
# 5   Araba/Álava        Vitoria-Gasteiz            1004
# 6   Araba/Álava        Vitoria-Gasteiz            1005
# 7   Araba/Álava        Vitoria-Gasteiz            1006
# 8   Araba/Álava        Vitoria-Gasteiz            1007
# 9   Araba/Álava        Vitoria-Gasteiz            1008
# 10  Araba/Álava        Vitoria-Gasteiz            1009
# 11  Araba/Álava        Vitoria-Gasteiz            1010
# 12  Araba/Álava        Vitoria-Gasteiz            1012
# 13  Araba/Álava      Labastida/Bastida            1012
# 14  Araba/Álava        Vitoria-Gasteiz            1013
# 15  Araba/Álava        Vitoria-Gasteiz            1015
# 16  Araba/Álava        Campezo/Kanpezu            1110
# 17  Araba/Álava        Campezo/Kanpezu            1117
# 18  Araba/Álava  Harana/Valle de Arana            1117
# 19       Burgos     Condado de Treviño            1118
# 20  Araba/Álava                Bernedo            1118
# 21  Araba/Álava                 Lagrán            1118
# 22  Araba/Álava          Arraia-Maeztu            1120
# 23  Araba/Álava        Campezo/Kanpezu            1128
# 24  Araba/Álava          Arraia-Maeztu            1128
# 25  Araba/Álava                Bernedo            1128
# 26  Araba/Álava          Arraia-Maeztu            1129
# 27  Araba/Álava                   Zuia            1130
# 28  Araba/Álava               Zigoitia            1138
# 29  Araba/Álava                   Zuia            1139

# %%
cpostal = df['codigopostalid']
cpostal
# Out:
# 0          240
# 1          548
# 2         1001
# 3         1002
# 4         1003
#          ...
# 14660    52004
# 14661    52005
# 14662    52006
# 14663    73820
# 14664    90007
# Name: codigopostalid, Length: 14665, dtype: int64

# %%
# Rellenamos con ceros a la izquierda los códigos postales con menos de 5 dígitos
ci = []
for i in cpostal:
    i=str(i)
    i = i.zfill(5)
    ci.append(i)

# %%
cp = pd.DataFrame(ci, columns=['cp'])
df['cp'] = cp
df.drop(columns='codigopostalid', inplace=True)
df.head(30)
# Out:
#       provincia              poblacion     cp
# 0   Araba/Álava       Alegría-Dulantzi  00240
# 1         Ávila              Candeleda  00548
# 2   Araba/Álava        Vitoria-Gasteiz  01001
# 3   Araba/Álava        Vitoria-Gasteiz  01002
# 4   Araba/Álava        Vitoria-Gasteiz  01003
# 5   Araba/Álava        Vitoria-Gasteiz  01004
# 6   Araba/Álava        Vitoria-Gasteiz  01005
# 7   Araba/Álava        Vitoria-Gasteiz  01006
# 8   Araba/Álava        Vitoria-Gasteiz  01007
# 9   Araba/Álava        Vitoria-Gasteiz  01008
# 10  Araba/Álava        Vitoria-Gasteiz  01009
# 11  Araba/Álava        Vitoria-Gasteiz  01010
# 12  Araba/Álava        Vitoria-Gasteiz  01012
# 13  Araba/Álava      Labastida/Bastida  01012
# 14  Araba/Álava        Vitoria-Gasteiz  01013
# 15  Araba/Álava        Vitoria-Gasteiz  01015
# 16  Araba/Álava        Campezo/Kanpezu  01110
# 17  Araba/Álava        Campezo/Kanpezu  01117
# 18  Araba/Álava  Harana/Valle de Arana  01117
# 19       Burgos     Condado de Treviño  01118
# 20  Araba/Álava                Bernedo  01118
# 21  Araba/Álava                 Lagrán  01118
# 22  Araba/Álava          Arraia-Maeztu  01120
# 23  Araba/Álava        Campezo/Kanpezu  01128
# 24  Araba/Álava          Arraia-Maeztu  01128
# 25  Araba/Álava                Bernedo  01128
# 26  Araba/Álava          Arraia-Maeztu  01129
# 27  Araba/Álava                   Zuia  01130
# 28  Araba/Álava               Zigoitia  01138
# 29  Araba/Álava                   Zuia  01139

# %%
cp = df.to_csv('codigo_postal.csv')

# %% [markdown]
# ## Tipos de perfiles

# %% [markdown]
# Creamos la tabla de perfiles con los datos trasladados desde UX

# %%
perfiles = pd.DataFrame({"Perfil" : ["Miembros", "Voluntarios", "Ambos", "Admin"],
                "Descripcion": ["Elige esta opción si buscas a alguien que te acompañe para solucionar tus problemas.", "Elige esta opción si buscas aportar tu granito de arena a la comunidad de mayores.", "Elige esta opción si buscas las dos opciones anteriores.", "Perfil administrador"],
                "img": ["miembros.png", "voluntarios.png", "ambos.png", " "]})
perfiles.to_csv('tipos_perfil.csv')

# %% [markdown]
# ## Tabla voluntarios (parte1)

# %%
voluntarios = {'Nombre':[], 'Apellidos':[]}
voluntarios
# Out:
# {'Nombre': [], 'Apellidos': []}

# %%
# Generamos nombre y apellidos ficticios con la librería faker

fake = Faker('es_ES')
fake.seed_instance(42)
for i in np.arange(0,500):
    name = fake.first_name()
    voluntarios['Nombre'].append(name)
    apellido = fake.unique.last_name()
    voluntarios['Apellidos'].append(apellido)

# %%
# Generamos aleatoriamente los números de teléfonos para completar este campo

tl = {'tl' : []}

for i in np.arange(0, 500):
    rand = random.randrange(600000000, 700000000)
    tl['tl'].append(rand)

tel = pd.DataFrame(tl)

# %%
# Elegimos un código postal aleatorio

cp = {'CP' : []}
for i in np.arange(0,500):
    rand = random.choice(df['cp'])
    cp['CP'].append(rand)

cp = pd.DataFrame(cp)

# %%
# Generamos contraseñas aleatorias para completar el campo pass

contr = {'pass': []}
for i in np.arange(0,500):
    rand = random.randrange(12345678, 87654321)
    contr['pass'].append(rand)

contr = pd.DataFrame(contr)

# %%
# Elegimos al azar los perfiles de Voluntario y Ambos

tipo_c = ['Voluntario', 'Ambos']
tipo = {'Tipo': []}
for i in np.arange(0,500):
    rand = random.choice(tipo_c)
    tipo['Tipo'].append(rand)

tipo = pd.DataFrame(tipo)

# %% [markdown]
# Creamos todas las combinaciones posibles de los servicios ofrecidos para introducirlas dentro de una lista.

# %%
servicios_c= [["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 	["Salud", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día", "Burocracia"], 	["Amigos y Ocio", "El día a día", "Burocracia", "Servicios del Municipio"], 	
["Nuevas Tecnologías", "Salud", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "El día a día"], 
["Nuevas Tecnologías", "El día a día", "Burocracia", "Servicios del Municipio"], 	
["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Servicios del Municipio"],
["Salud", "Amigos y Ocio", "El día a día", "Burocracia"], ["Salud", "El día a día", "Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "El día a día", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio", "Burocracia"],
["Salud", "Amigos y Ocio", "El día a día", "Servicios del Municipio"],
["Nuevas Tecnologías", "Amigos y Ocio", "El día a día", "Burocracia"],
["El día a día", "Burocracia", "Servicios del Municipio"], ["Nuevas Tecnologías", "Salud", "Amigos y Ocio"],
["Salud", "El día a día", "Servicios del Municipio"], 	["Nuevas Tecnologías", "Amigos y Ocio", "Burocracia"], 
["Nuevas Tecnologías", "Burocracia", "Servicios del Municipio"], 
["Nuevas Tecnologías", "Salud", "Servicios del Municipio"], 
["Salud", "Amigos y Ocio", "Servicios del Municipio"], ["Nuevas Tecnologías", "Amigos y Ocio", "El día a día"], 
["Nuevas Tecnologías", "Salud", "El día a día"], ["Amigos y Ocio", "Burocracia", "Servicios del Municipio"], 
["Amigos y Ocio", "El día a día", "Servicios del Municipio"], ["Amigos y Ocio", "El día a día", "Burocracia"], 
["Nuevas Tecnologías", "El día a día", "Servicios del Municipio"],
["Nuevas Tecnologías", "El día a día", "Burocracia"], ["Salud", "Burocracia", "Servicios del Municipio"], ["Nuevas Tecnologías", "Amigos y Ocio", "Servicios del Municipio"],
["Nuevas Tecnologías", "Salud"], ["Nuevas Tecnologías", "Amigos y Ocio"],
["Nuevas Tecnologías", "El día a día"], ["Nuevas Tecnologías", "Burocracia"], 
["Nuevas Tecnologías", "Servicios del Municipio"], ["Salud", "Amigos y Ocio"], 
["Salud", "El día a día"], 	["Salud", "Burocracia"], ["Salud", "Servicios del Municipio"],
["Amigos y Ocio", "El día a día"], 	["Amigos y Ocio", "Burocracia"], 
["Amigos y Ocio", "Servicios del Municipio"], ["El día a día", "Burocracia"], 
["El día a día", "Servicios del Municipio"], ["Burocracia", "Servicios del Municipio"],
["Nuevas Tecnologías"], ["Salud"], 	["Amigos y Ocio"],
   ["El día a día"], ["Burocracia"], ["Servicios del Municipio"]]


servicios = {'Servicios disponibles': []}
for i in np.arange(0,500):
    rand = random.choice(servicios_c)
    servicios['Servicios disponibles'].append(rand)

servicios = pd.DataFrame(servicios)

# %%
# Creamos aleatorio el status de los voluntarios (0 = no disponible, 1 =  disponible)
s = [0, 1]
status={'Status': []}
for i in np.arange(0,500):
    rand = random.choice(s)
    status['Status'].append(rand)

status = pd.DataFrame(status)

# %% [markdown]
# Imagenes descargadas de figma y renombradas para utilizar aleatoriamente en las tablas de voluntarios y miembros

# %%
imagenes = ["hombre1.png","hombre2.png","miembroh1.png","miembroh3.png","miembrom3.png","miembrom4.png",
"mujer1.png","mujer2.png","opinion1.png","opinion2m.png","opinion3m.png","opinion4.png","opinion5m.png",
"opinion6.png"]

# %%
# Introducimos aleatoriamente las fotografías para cada uno de los voluntarios

img_vol = ["hombre1.png","mujer1.png", "hombre2.png","mujer2.png"]
img_v={'Foto vol': []}
for i in np.arange(0,500):
    rand = random.choice(img_vol)
    img_v['Foto vol'].append(rand)

img_v = pd.DataFrame(img_v)

# %% [markdown]
# Se generar mini biografías para el perfil de los voluntarios

# %%
bio1 = "Soy una persona muy atenta. Me gusta aportar mi granito de arena siempre que puedo. Estaría encantada de poder acompañarte en lo que necesites."
bio2 = "Me encanta sertirme útil y por eso estaría encantada de poder ayudarte."
bio3 = "Me gusta trabajar con otras personas, codo con codo, sumando fuerzas, compartiendo experiencias y aprendiendo unas de otras, creciendo juntos."
bio4 = "Soy una persona a la que le fascina conocer personas diferentes y aprender de los demas para conseguir un objetivo común."
bio5 = "Me gusta pasar mi tiempo ayudando a los demás y hacer nuevos amigos."
bio6 = "Quiero devolver a la comunidad lo que me dieron sin pedir nada a cambio."

# %%
bios = [bio1, bio2, bio3, bio4, bio5, bio6]
bio = {'Bio': []}
for i in np.arange(0,500):
    rand = random.choice(bios)
    bio['Bio'].append(rand)

bio = pd.DataFrame(bio)

# %% [markdown]
# Para generar fechas aleatorias entre rangos utilizamos la función del siguiente recurso:
#
# https://es.stackoverflow.com/questions/418863/como-generar-una-fecha-aleatoria-entre-dos-rangos-con-random-randit-en-python

# %%
from random import randint
from datetime import datetime


DATE_FORMAT = '%d/%m/%Y'


def get_random_date_between(date_a, date_b):    
    datetime_object_a = datetime.strptime(date_a, DATE_FORMAT)
    datetime_object_b = datetime.strptime(date_b, DATE_FORMAT)

    random_ordinal = randint(
        datetime_object_a.toordinal(),
        datetime_object_b.toordinal(),
    )

    random_date = datetime.fromordinal(random_ordinal)
    formatted_date_string = random_date.strftime(DATE_FORMAT)

    return formatted_date_string

get_random_date_between('17/5/2019', '30/6/2022')
# Out:
# '21/11/2021'

# %%
# Generamos fechas aleatorias de registro de voluntarios

f_insc = {'Fecha inscripcion': []}
for i in np.arange(0,500):
    rand = get_random_date_between('17/5/2019', '30/6/2022')
    f_insc['Fecha inscripcion'].append(rand)

inscripcion = pd.DataFrame(f_insc)

# %%
# unificamos en un único DataFrame todos los campos creados anteriormente

voluntarios = pd.DataFrame(voluntarios)
voluntarios['Movil'] = tel
voluntarios['Codigo Postal'] = cp
voluntarios['Pass'] = contr
voluntarios['Perfil'] = tipo
voluntarios['Servicios Disponibles'] = servicios
voluntarios['Status'] = status
voluntarios['FotoV'] = img_v
voluntarios['Bio'] = bio
voluntarios['Fecha inscripcion'] = inscripcion
voluntarios.head(5)
# Out:
#          Nombre  Apellidos      Movil Codigo Postal      Pass      Perfil  \
# 0     Feliciana     Cantón  620034908         39682  82499295       Ambos
# 1        Amador     Llopis  665288077         27277  62909541       Ambos
# 2  Jose Ignacio      Godoy  675211243         50366  72406087  Voluntario
# 3        Emilio  Calatayud  688454142         19432  55533241  Voluntario
# 4    Inmaculada      Bonet  668697667         41950  32120399  Voluntario
#
#                                Servicios Disponibles  Status        FotoV  \
# 0                               [Nuevas Tecnologías]       1   mujer1.png
# 1                              [Salud, El día a día]       0  hombre1.png
# 2                [Nuevas Tecnologías, Amigos y Ocio]       0   mujer2.png
# 3                              [Salud, El día a día]       1  hombre2.png
# 4  [Nuevas Tecnologías, Salud, Servicios del Muni...       1   mujer1.png
#
#                                                  Bio Fecha inscripcion
# 0  Me gusta trabajar con otras personas, codo con...        16/02/2021
# 1  Quiero devolver a la comunidad lo que me diero...        15/03/2022
# 2  Me gusta pasar mi tiempo ayudando a los demás ...        23/02/2020
# 3  Me encanta sertirme útil y por eso estaría enc...        20/01/2020
# 4  Me gusta pasar mi tiempo ayudando a los demás ...        01/02/2022

# %%
# Unimos los campos Nombre y Apellidos

voluntarios.insert(2, 'Nombre y Apellidos', voluntarios[['Nombre', 'Apellidos']].apply(' '.join, axis=1))

# %% [markdown]
# ## Miembros

# %% [markdown]
# Creamos la base de datos con los campos de los miembros.
# Añadimos las imágenes distintas de voluntarios para esta tabla.

# %%
miembros = {'Nombre':[], 'Apellidos':[], 'Movil': [], 'CP': [], 'pass': [], 'Foto miembro' : [], 'Fecha inscripcion' : []}

# %%
img_m = ["miembroh1.png","miembroh3.png","miembrom3.png","miembrom4.png", "opinion1.png","opinion2m.png",
"opinion3m.png","opinion4.png","opinion5m.png","opinion6.png"]

# %%
# Generamos aleatoriamente los campos de nombre, apellidos, móvil, código postal, pass, imagen y fecha de inscripción

fake = Faker('es_ES')
fake.seed_instance(100)
for i in np.arange(0,1000):
    name = fake.first_name()
    miembros['Nombre'].append(name)
    apellido = fake.unique.last_name()
    miembros['Apellidos'].append(apellido)
    rand = random.randrange(600000000, 700000000)
    miembros['Movil'].append(rand)
    postal = random.choice(df['cp'])
    miembros['CP'].append(postal)
    cont = random.randrange(12345678, 87654321)
    miembros['pass'].append(cont)
    img = random.choice(img_m)
    miembros['Foto miembro'].append(img)
    fecha = get_random_date_between('17/5/2019', '30/6/2022')
    miembros['Fecha inscripcion'].append(fecha)

miembros = pd.DataFrame(miembros)
miembros.head(30)
# Out:
#        Nombre  Apellidos      Movil     CP      pass   Foto miembro  \
# 0     Esteban     Segura  676741618  27247  82359331   opinion4.png
# 1      Wálter       Díaz  610642355  08293  21524550  miembrom4.png
# 2     Julieta       Pozo  681757413  10866  58232070   opinion4.png
# 3      Lupita       Olmo  632364118  30878  31727747   opinion4.png
# 4     Toribio   Vendrell  614984177  36378  62095009  opinion3m.png
# 5     Nereida      Canet  614037781  43700  26513656   opinion1.png
# 6       Berta    Carrión  668933534  41728  84113067  miembrom3.png
# 7     Cecilio  Sarmiento  694327771  50660  32322750  miembroh1.png
# 8   Juan José    Asensio  616038085  49881  28959071  miembroh1.png
# 9    Genoveva     Fuente  677012813  24640  24084393  miembrom4.png
# 10       Nico       Gras  699975455  06390  80191147  miembroh1.png
# 11     Martin      Frías  649528513  24156  17656307   opinion4.png
# 12     Gaspar      Chico  696198414  35540  66696661   opinion4.png
# 13    Gonzalo     Oliver  686995419  20749  78902043  miembroh3.png
# 14     Rafael    Redondo  618633372  16290  76607867  opinion5m.png
# 15    Perlita     Galvez  609165702  22110  78649948   opinion4.png
# 16     Samuel      Serra  625778344  01118  70174531  opinion2m.png
# 17   Catalina    Llorens  654624555  17700  80788088   opinion4.png
# 18  Valentina      Perez  603176245  08011  74148686  miembrom3.png
# 19     Felipe   Casanova  650024054  36589  38743744  miembrom4.png
# 20    Geraldo       Adán  671099854  17111  35873672  miembrom3.png
# 21      Elisa     Priego  645047760  37185  25226985  miembroh1.png
# 22    Eusebio     Cámara  637558381  09613  25415743   opinion4.png
# 23  Guadalupe      Diego  697257044  08461  30322152   opinion4.png
# 24  Prudencia        Amo  685405015  37864  13032458   opinion4.png
# 25    Xiomara     Gálvez  639027226  14130  87401143  miembroh1.png
# 26  Victorino      Ponce  651676146  03710  22943830   opinion6.png
# 27    Edmundo      Badía  658432387  18313  65957694  opinion5m.png
# 28    Emelina    Huertas  686416398  22820  26035485  opinion3m.png
# 29    Liliana     Manjón  688806514  47131  22374285  opinion2m.png
#
#    Fecha inscripcion
# 0         24/12/2021
# 1         30/06/2021
# 2         11/06/2022
# 3         07/12/2019
# 4         28/11/2019
# 5         07/05/2021
# 6         19/10/2019
# 7         13/05/2021
# 8         26/06/2020
# 9         18/03/2020
# 10        28/05/2021
# 11        22/01/2022
# 12        31/10/2021
# 13        08/02/2022
# 14        07/10/2021
# 15        04/06/2021
# 16        15/11/2021
# 17        09/05/2020
# 18        19/11/2020
# 19        21/03/2022
# 20        21/11/2020
# 21        27/03/2021
# 22        18/05/2022
# 23        22/06/2020
# 24        16/04/2022
# 25        24/01/2020
# 26        17/01/2021
# 27        29/10/2020
# 28        17/12/2021
# 29        11/03/2020

# %%
# Unificamos la columna Nombre y Apellidos

miembros.insert(2, 'Nombre y Apellidos', miembros[['Nombre', 'Apellidos']].apply(' '.join, axis=1))

# %%
# Filtramos los usuarios con perfil "Ambos" de la tabla de voluntarios para poder añadirlos a la tabla de Miembros

masm = voluntarios[voluntarios['Perfil'] == 'Ambos']
masm
# Out:
#         Nombre Apellidos  Nombre y Apellidos      Movil Codigo Postal  \
# 0    Feliciana    Cantón    Feliciana Cantón  620034908         39682
# 1       Amador    Llopis       Amador Llopis  665288077         27277
# 5      Dominga      Roca        Dominga Roca  686133039         43530
# 8         Joan   Vazquez        Joan Vazquez  648703191         27256
# 9       Eligia      Amor         Eligia Amor  683377432         16432
# ..         ...       ...                 ...        ...           ...
# 491      Ángel      Jara          Ángel Jara  638251729         27468
# 493  Valentina  Benavent  Valentina Benavent  657923341         16195
# 496  Feliciana   Rodrigo   Feliciana Rodrigo  688310774         37340
# 497      Jenny     Matas         Jenny Matas  677536704         45191
# 498  Heliodoro    Planas    Heliodoro Planas  647337557         19244
#
#          Pass Perfil                              Servicios Disponibles  \
# 0    82499295  Ambos                               [Nuevas Tecnologías]
# 1    62909541  Ambos                              [Salud, El día a día]
# 5    37204203  Ambos  [Nuevas Tecnologías, Salud, Servicios del Muni...
# 8    35855870  Ambos  [Nuevas Tecnologías, Salud, Amigos y Ocio, El ...
# 9    84214312  Ambos           [Amigos y Ocio, Servicios del Municipio]
# ..        ...    ...                                                ...
# 491  30010079  Ambos  [Salud, Amigos y Ocio, El día a día, Burocraci...
# 493  45721137  Ambos  [Nuevas Tecnologías, El día a día, Servicios d...
# 496  31676343  Ambos  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 497  57135343  Ambos    [Nuevas Tecnologías, Amigos y Ocio, Burocracia]
# 498  82067379  Ambos          [Nuevas Tecnologías, Salud, El día a día]
#
#      Status        FotoV                                                Bio  \
# 0         1   mujer1.png  Me gusta trabajar con otras personas, codo con...
# 1         0  hombre1.png  Quiero devolver a la comunidad lo que me diero...
# 5         1  hombre2.png  Me gusta pasar mi tiempo ayudando a los demás ...
# 8         1  hombre2.png  Soy una persona a la que le fascina conocer pe...
# 9         0   mujer2.png  Soy una persona muy atenta. Me gusta aportar m...
# ..      ...          ...                                                ...
# 491       1   mujer1.png  Quiero devolver a la comunidad lo que me diero...
# 493       0  hombre2.png  Me gusta trabajar con otras personas, codo con...
# 496       1   mujer1.png  Me gusta trabajar con otras personas, codo con...
# 497       1   mujer2.png  Soy una persona a la que le fascina conocer pe...
# 498       0  hombre2.png  Quiero devolver a la comunidad lo que me diero...
#
#     Fecha inscripcion
# 0          16/02/2021
# 1          15/03/2022
# 5          04/09/2020
# 8          02/01/2022
# 9          18/04/2020
# ..                ...
# 491        13/12/2021
# 493        10/06/2021
# 496        13/03/2022
# 497        16/12/2021
# 498        21/02/2021
#
# [260 rows x 12 columns]

# %%
# Del filtro realizado, eliminamos las columnas que no corresponden a la categoría "Miembro"
miembro = masm.drop(columns=['Perfil', 'Servicios Disponibles', 'Status', 'Bio'])
miembro
# Out:
#         Nombre Apellidos  Nombre y Apellidos      Movil Codigo Postal  \
# 0    Feliciana    Cantón    Feliciana Cantón  620034908         39682
# 1       Amador    Llopis       Amador Llopis  665288077         27277
# 5      Dominga      Roca        Dominga Roca  686133039         43530
# 8         Joan   Vazquez        Joan Vazquez  648703191         27256
# 9       Eligia      Amor         Eligia Amor  683377432         16432
# ..         ...       ...                 ...        ...           ...
# 491      Ángel      Jara          Ángel Jara  638251729         27468
# 493  Valentina  Benavent  Valentina Benavent  657923341         16195
# 496  Feliciana   Rodrigo   Feliciana Rodrigo  688310774         37340
# 497      Jenny     Matas         Jenny Matas  677536704         45191
# 498  Heliodoro    Planas    Heliodoro Planas  647337557         19244
#
#          Pass        FotoV Fecha inscripcion
# 0    82499295   mujer1.png        16/02/2021
# 1    62909541  hombre1.png        15/03/2022
# 5    37204203  hombre2.png        04/09/2020
# 8    35855870  hombre2.png        02/01/2022
# 9    84214312   mujer2.png        18/04/2020
# ..        ...          ...               ...
# 491  30010079   mujer1.png        13/12/2021
# 493  45721137  hombre2.png        10/06/2021
# 496  31676343   mujer1.png        13/03/2022
# 497  57135343   mujer2.png        16/12/2021
# 498  82067379  hombre2.png        21/02/2021
#
# [260 rows x 8 columns]

# %%
# Renombramos las columnas para que correspondan a las mismas que la tabla Miembros

miembro.columns= ['Nombre', 'Apellidos', 'Nombre y Apellidos', 'Movil', 'CP', 'pass',
       'Foto miembro', 'Fecha inscripcion']
miembro
# Out:
#         Nombre Apellidos  Nombre y Apellidos      Movil     CP      pass  \
# 0    Feliciana    Cantón    Feliciana Cantón  620034908  39682  82499295
# 1       Amador    Llopis       Amador Llopis  665288077  27277  62909541
# 5      Dominga      Roca        Dominga Roca  686133039  43530  37204203
# 8         Joan   Vazquez        Joan Vazquez  648703191  27256  35855870
# 9       Eligia      Amor         Eligia Amor  683377432  16432  84214312
# ..         ...       ...                 ...        ...    ...       ...
# 491      Ángel      Jara          Ángel Jara  638251729  27468  30010079
# 493  Valentina  Benavent  Valentina Benavent  657923341  16195  45721137
# 496  Feliciana   Rodrigo   Feliciana Rodrigo  688310774  37340  31676343
# 497      Jenny     Matas         Jenny Matas  677536704  45191  57135343
# 498  Heliodoro    Planas    Heliodoro Planas  647337557  19244  82067379
#
#     Foto miembro Fecha inscripcion
# 0     mujer1.png        16/02/2021
# 1    hombre1.png        15/03/2022
# 5    hombre2.png        04/09/2020
# 8    hombre2.png        02/01/2022
# 9     mujer2.png        18/04/2020
# ..           ...               ...
# 491   mujer1.png        13/12/2021
# 493  hombre2.png        10/06/2021
# 496   mujer1.png        13/03/2022
# 497   mujer2.png        16/12/2021
# 498  hombre2.png        21/02/2021
#
# [260 rows x 8 columns]

# %%
# Apilamos la nueva tabla filtrada desde voluntarios a la ya existente de Miembros

miembrosf = pd.concat([miembros, miembro], axis=0)
miembrosf.reset_index(inplace=True)
miembrosf.drop(columns=['index'],inplace=True)
miembrosf
# Out:
#          Nombre Apellidos  Nombre y Apellidos      Movil     CP      pass  \
# 0       Esteban    Segura      Esteban Segura  676741618  27247  82359331
# 1        Wálter      Díaz         Wálter Díaz  610642355  08293  21524550
# 2       Julieta      Pozo        Julieta Pozo  681757413  10866  58232070
# 3        Lupita      Olmo         Lupita Olmo  632364118  30878  31727747
# 4       Toribio  Vendrell    Toribio Vendrell  614984177  36378  62095009
# ...         ...       ...                 ...        ...    ...       ...
# 1255      Ángel      Jara          Ángel Jara  638251729  27468  30010079
# 1256  Valentina  Benavent  Valentina Benavent  657923341  16195  45721137
# 1257  Feliciana   Rodrigo   Feliciana Rodrigo  688310774  37340  31676343
# 1258      Jenny     Matas         Jenny Matas  677536704  45191  57135343
# 1259  Heliodoro    Planas    Heliodoro Planas  647337557  19244  82067379
#
#        Foto miembro Fecha inscripcion
# 0      opinion4.png        24/12/2021
# 1     miembrom4.png        30/06/2021
# 2      opinion4.png        11/06/2022
# 3      opinion4.png        07/12/2019
# 4     opinion3m.png        28/11/2019
# ...             ...               ...
# 1255     mujer1.png        13/12/2021
# 1256    hombre2.png        10/06/2021
# 1257     mujer1.png        13/03/2022
# 1258     mujer2.png        16/12/2021
# 1259    hombre2.png        21/02/2021
#
# [1260 rows x 8 columns]

# %%
miembrosf.to_csv('miembros.csv')

# %% [markdown]
# ## Opiniones

# %% [markdown]
# Para realizar la tabla de opiniones se necesita a los voluntarios con sus áreas, además de los miembros que han realizado dicha reseña, puntuación y la reseña.

# %%
# Nos quedamos con los voluntarios y sus áreas de actuación

opiniones = voluntarios.iloc[:,2:8:5]
opiniones
# Out:
#      Nombre y Apellidos                              Servicios Disponibles
# 0      Feliciana Cantón                               [Nuevas Tecnologías]
# 1         Amador Llopis                              [Salud, El día a día]
# 2    Jose Ignacio Godoy                [Nuevas Tecnologías, Amigos y Ocio]
# 3      Emilio Calatayud                              [Salud, El día a día]
# 4      Inmaculada Bonet  [Nuevas Tecnologías, Salud, Servicios del Muni...
# ..                  ...                                                ...
# 495      Diana Martínez          [Nuevas Tecnologías, Salud, El día a día]
# 496   Feliciana Rodrigo  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
# 497         Jenny Matas    [Nuevas Tecnologías, Amigos y Ocio, Burocracia]
# 498    Heliodoro Planas          [Nuevas Tecnologías, Salud, El día a día]
# 499         Reyna Tomas              [Burocracia, Servicios del Municipio]
#
# [500 rows x 2 columns]

# %%
# Para generar más opiniones, cogemos un rango intermedio de la tabla anterior para apilarla.

res2 = opiniones.iloc[125:340, :2]
res2.reset_index(inplace=True)
res2.drop(columns=['index'],inplace=True)
res2
# Out:
#     Nombre y Apellidos                              Servicios Disponibles
# 0     Jose Ramón Feliu                   [Salud, Servicios del Municipio]
# 1        Goyo Sanabria                        [Amigos y Ocio, Burocracia]
# 2      Enrique Español  [Nuevas Tecnologías, Salud, El día a día, Buro...
# 3       León Sevillano     [Nuevas Tecnologías, El día a día, Burocracia]
# 4          Josep Benet              [Burocracia, Servicios del Municipio]
# ..                 ...                                                ...
# 210      Gabriel Vélez     [Nuevas Tecnologías, El día a día, Burocracia]
# 211       Florina León                                            [Salud]
# 212  Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 213        Adela Ruano  [Nuevas Tecnologías, Salud, El día a día, Buro...
# 214      Paola Ledesma  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
#
# [215 rows x 2 columns]

# %%
# Unificamos las dos tablas

resenas = pd.concat([opiniones, res2], axis=0)
resenas.reset_index(inplace=True)
resenas.drop(columns=['index'],inplace=True)
resenas
# Out:
#      Nombre y Apellidos                              Servicios Disponibles
# 0      Feliciana Cantón                               [Nuevas Tecnologías]
# 1         Amador Llopis                              [Salud, El día a día]
# 2    Jose Ignacio Godoy                [Nuevas Tecnologías, Amigos y Ocio]
# 3      Emilio Calatayud                              [Salud, El día a día]
# 4      Inmaculada Bonet  [Nuevas Tecnologías, Salud, Servicios del Muni...
# ..                  ...                                                ...
# 710       Gabriel Vélez     [Nuevas Tecnologías, El día a día, Burocracia]
# 711        Florina León                                            [Salud]
# 712   Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 713         Adela Ruano  [Nuevas Tecnologías, Salud, El día a día, Buro...
# 714       Paola Ledesma  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
#
# [715 rows x 2 columns]

# %%
# Aleatoriamente asignamos una calificación a cada uno de los registros creados

estrellas = [1,2,3,4,5]
resena = {'Estrellas':[]}

for i in np.arange(0,715):
    clas = random.choice(estrellas)
    resena['Estrellas'].append(clas)

resena = pd.DataFrame(resena)
resenas['Estrellas'] = resena
resenas.head()
# Out:
#    Nombre y Apellidos                              Servicios Disponibles  \
# 0    Feliciana Cantón                               [Nuevas Tecnologías]
# 1       Amador Llopis                              [Salud, El día a día]
# 2  Jose Ignacio Godoy                [Nuevas Tecnologías, Amigos y Ocio]
# 3    Emilio Calatayud                              [Salud, El día a día]
# 4    Inmaculada Bonet  [Nuevas Tecnologías, Salud, Servicios del Muni...
#
#    Estrellas
# 0          5
# 1          3
# 2          1
# 3          4
# 4          5

# %% [markdown]
# Creamos distintos textos de opiniones para asignar en función de la puntuación registrada

# %%
op1 = ["Al final tuvo que irse antes", "El día podría haber estado mejor", "Llegó tarde", "No es muy habladora",
"No habla mucho", "No me arregló los papeles", "No me ayudó nada", "No me entendía", "No me pudo acompañar donde yo quería",
"No pudo ayudarme", "No sabía lo que le pedía", "Tuvo muy poca paciencia"]
op2 = ["Bueno, podría mejorar", "El servicio no estuvo mal", "Es amable aunque no divertida",
"Está normal", "Ha llegado tarde", "No ha ido mal", "No ha podido ayudarme en lo que necesitaba", 
"No sabía lo que le pedía", "No terminó de ayudarme", "Puede mejorar"]
op3 = ["Bien", "Es muy amable", "Estoy contenta", "Gracias", "Gran dia", "Ha estado bien", "Ha estado muy bien",
"Ha podido ayudarme en algunas cosas", "Me acompañó en lo que necesitaba", "Me ayudó en lo que necesitaba",
"Me ayudó mucho en casa", "Me ha ayudado en lo que le he pedido", "Me ha ayudado mucho", "Me ha resuelto muchas dudas",
"Me lo he pasado bien", "No hemos terminado de congeniar pero ha estado bien", "Un día agradable"]
op4 = ["Es un encanto y me ayudó a hablar con mis nietos", "Es un sol, me ayudó a desbloquear el móvil y lo arregló",
"Fue un día estupendo", "No hubiera podido está más feliz", "No puedo estar más agradecida"]
op5 = ["Encantado con toda la ayuda que he recibido", "Es un encanto y me ayudó a hablar con mis nietos",
"Es un sol, me ayudó a desbloquear el móvil y lo arregló", "Fue un día estupendo", "Gracias, ha sido toda una experiencia",
"Me ayudó mucho en casa", "No hubiera podido estar más feliz", "No puedo estar más agradecida",
"Qué bien que pudo ayudarme con mis papeles", "Sin duda seguiré utilizando este servicio"]

# %%
# En función de la puntuación asignada se elige un comentario aleatorio de los posibles.

op = {'Opinión' : []}
for i in np.arange(0, 715):
    if resenas['Estrellas'][i] == 1:
        op_1 = random.choice(op1)
        op['Opinión'].append(op_1)
    elif resenas['Estrellas'][i] == 2:
        op_2 = random.choice(op2)
        op['Opinión'].append(op_2)
    elif resenas['Estrellas'][i] == 3:
        op_3 = random.choice(op3)
        op['Opinión'].append(op_3)
    elif resenas['Estrellas'][i] == 4:
        op_4 = random.choice(op4)
        op['Opinión'].append(op_4)
    elif resenas['Estrellas'][i] == 5:
        op_5 = random.choice(op5)
        op['Opinión'].append(op_5)

opi = pd.DataFrame(op)
resenas['Opinion'] = opi
resenas.head()
# Out:
#    Nombre y Apellidos                              Servicios Disponibles  \
# 0    Feliciana Cantón                               [Nuevas Tecnologías]
# 1       Amador Llopis                              [Salud, El día a día]
# 2  Jose Ignacio Godoy                [Nuevas Tecnologías, Amigos y Ocio]
# 3    Emilio Calatayud                              [Salud, El día a día]
# 4    Inmaculada Bonet  [Nuevas Tecnologías, Salud, Servicios del Muni...
#
#    Estrellas                        Opinion
# 0          5         Me ayudó mucho en casa
# 1          3  Me ayudó en lo que necesitaba
# 2          1      No me arregló los papeles
# 3          4  No puedo estar más agradecida
# 4          5  No puedo estar más agradecida

# %%
# De la tabla de miembros final elegimos un rango intermedio que añadiremos al Dataframe de reseñas

miemb = miembrosf.iloc[303:1018,2::4]
miemb.reset_index(inplace=True)
miemb.drop(columns=['index'], inplace=True)
miemb
# Out:
#     Nombre y Apellidos   Foto miembro
# 0           Morena Pol   opinion6.png
# 1          Chelo Rojas  miembroh1.png
# 2           Alma Luque  miembrom3.png
# 3      Ascensión Anaya  miembrom3.png
# 4        Leire Quiroga   opinion1.png
# ..                 ...            ...
# 710       Artemio Goñi    hombre1.png
# 711     Roxana Cabrero    hombre2.png
# 712     Fabiola Patiño     mujer2.png
# 713    Fermín Pellicer     mujer1.png
# 714      Herminia Lasa    hombre1.png
#
# [715 rows x 2 columns]

# %%
opinions = pd.concat([resenas, miemb], axis=1, ignore_index=True)
opinions.columns = ['Nombre voluntario', 'Servicios Disponibles', 'Estrellas', 'Opinion', 'Nombre miembro', 'Foto miembro']
opinions
# Out:
#       Nombre voluntario                              Servicios Disponibles  \
# 0      Feliciana Cantón                               [Nuevas Tecnologías]
# 1         Amador Llopis                              [Salud, El día a día]
# 2    Jose Ignacio Godoy                [Nuevas Tecnologías, Amigos y Ocio]
# 3      Emilio Calatayud                              [Salud, El día a día]
# 4      Inmaculada Bonet  [Nuevas Tecnologías, Salud, Servicios del Muni...
# ..                  ...                                                ...
# 710       Gabriel Vélez     [Nuevas Tecnologías, El día a día, Burocracia]
# 711        Florina León                                            [Salud]
# 712   Encarnación Tomás  [Nuevas Tecnologías, Salud, Amigos y Ocio, Bur...
# 713         Adela Ruano  [Nuevas Tecnologías, Salud, El día a día, Buro...
# 714       Paola Ledesma  [Nuevas Tecnologías, Amigos y Ocio, El día a d...
#
#      Estrellas                        Opinion   Nombre miembro   Foto miembro
# 0            5         Me ayudó mucho en casa       Morena Pol   opinion6.png
# 1            3  Me ayudó en lo que necesitaba      Chelo Rojas  miembroh1.png
# 2            1      No me arregló los papeles       Alma Luque  miembrom3.png
# 3            4  No puedo estar más agradecida  Ascensión Anaya  miembrom3.png
# 4            5  No puedo estar más agradecida    Leire Quiroga   opinion1.png
# ..         ...                            ...              ...            ...
# 710          3               Un día agradable     Artemio Goñi    hombre1.png
# 711          4  No puedo estar más agradecida   Roxana Cabrero    hombre2.png
# 712          3                       Gran dia   Fabiola Patiño     mujer2.png
# 713          3                 Estoy contenta  Fermín Pellicer     mujer1.png
# 714          3               Un día agradable    Herminia Lasa    hombre1.png
#
# [715 rows x 6 columns]

# %%
opinions.to_csv('opiniones.csv')

# %% [markdown]
# ## Voluntarios (parte2)

# %% [markdown]
# En la tabla de voluntarios añadiremos una columna con la media de las puntuaciones indicadas en la tabla de opiniones
# y otra columna con el número de opiniones de cada uno de los voluntarios

# %%
star = pd.Series(opinions.groupby(['Nombre voluntario']).Estrellas.mean().round(1), name='Estrellas')
count = pd.Series(opinions.groupby(['Nombre voluntario']).Opinion.count(), name='N_opinion')
df3 = pd.DataFrame([star, count])

# %%
df3 = df3.T
df3.reset_index(inplace=True)

df3
# Out:
#     Nombre voluntario  Estrellas  N_opinion
# 0        Abril Ibañez        2.5        2.0
# 1          Adela Jaén        2.0        2.0
# 2         Adela Ruano        4.0        2.0
# 3     Adela Salamanca        2.5        2.0
# 4        Adelina Vall        5.0        1.0
# ..                ...        ...        ...
# 495      Ángeles Sanz        2.5        2.0
# 496     Áurea Maestre        4.0        1.0
# 497      Íñigo Carpio        3.0        1.0
# 498   Úrsula Belmonte        4.0        2.0
# 499      Úrsula Perez        3.0        2.0
#
# [500 rows x 3 columns]

# %%
df3['N_opinion'] = df3['N_opinion'].astype('int64', errors='ignore')

# %%
# Unimos la tabla generada con la media de las puntuaciones y el número de opiniones a la tabla de voluntarios

voluntariosf= pd.merge(left= voluntarios, right= df3, how = 'outer', left_on=voluntarios['Nombre y Apellidos'], 
                        right_on=df3['Nombre voluntario'])

voluntariosf
# Out:
#                   key_0        Nombre  Apellidos  Nombre y Apellidos  \
# 0      Feliciana Cantón     Feliciana     Cantón    Feliciana Cantón
# 1         Amador Llopis        Amador     Llopis       Amador Llopis
# 2    Jose Ignacio Godoy  Jose Ignacio      Godoy  Jose Ignacio Godoy
# 3      Emilio Calatayud        Emilio  Calatayud    Emilio Calatayud
# 4      Inmaculada Bonet    Inmaculada      Bonet    Inmaculada Bonet
# ..                  ...           ...        ...                 ...
# 495      Diana Martínez         Diana   Martínez      Diana Martínez
# 496   Feliciana Rodrigo     Feliciana    Rodrigo   Feliciana Rodrigo
# 497         Jenny Matas         Jenny      Matas         Jenny Matas
# 498    Heliodoro Planas     Heliodoro     Planas    Heliodoro Planas
# 499         Reyna Tomas         Reyna      Tomas         Reyna Tomas
#
#          Movil Codigo Postal      Pass      Perfil  \
# 0    620034908         39682  82499295       Ambos
# 1    665288077         27277  62909541       Ambos
# 2    675211243         50366  72406087  Voluntario
# 3    688454142         19432  55533241  Voluntario
# 4    668697667         41950  32120399  Voluntario
# ..         ...           ...       ...         ...
# 495  678607314         47200  60206242  Voluntario
# 496  688310774         37340  31676343       Ambos
# 497  677536704         45191  57135343       Ambos
# 498  647337557         19244  82067379       Ambos
# 499  657750872         06718  57067694  Voluntario
#
#                                  Servicios Disponibles  Status        FotoV  \
# 0                                 [Nuevas Tecnologías]       1   mujer1.png
# 1                                [Salud, El día a día]       0  hombre1.png
# 2                  [Nuevas Tecnologías, Amigos y Ocio]       0   mujer2.png
# 3                                [Salud, El día a día]       1  hombre2.png
# 4    [Nuevas Tecnologías, Salud, Servicios del Muni...       1   mujer1.png
# ..                                                 ...     ...          ...
# 495          [Nuevas Tecnologías, Salud, El día a día]       0  hombre2.png
# 496  [Nuevas Tecnologías, Amigos y Ocio, El día a d...       1   mujer1.png
# 497    [Nuevas Tecnologías, Amigos y Ocio, Burocracia]       1   mujer2.png
# 498          [Nuevas Tecnologías, Salud, El día a día]       0  hombre2.png
# 499              [Burocracia, Servicios del Municipio]       0  hombre2.png
#
#                                                    Bio Fecha inscripcion  \
# 0    Me gusta trabajar con otras personas, codo con...        16/02/2021
# 1    Quiero devolver a la comunidad lo que me diero...        15/03/2022
# 2    Me gusta pasar mi tiempo ayudando a los demás ...        23/02/2020
# 3    Me encanta sertirme útil y por eso estaría enc...        20/01/2020
# 4    Me gusta pasar mi tiempo ayudando a los demás ...        01/02/2022
# ..                                                 ...               ...
# 495  Quiero devolver a la comunidad lo que me diero...        17/02/2022
# 496  Me gusta trabajar con otras personas, codo con...        13/03/2022
# 497  Soy una persona a la que le fascina conocer pe...        16/12/2021
# 498  Quiero devolver a la comunidad lo que me diero...        21/02/2021
# 499  Soy una persona muy atenta. Me gusta aportar m...        28/08/2020
#
#       Nombre voluntario  Estrellas  N_opinion
# 0      Feliciana Cantón        5.0          1
# 1         Amador Llopis        3.0          1
# 2    Jose Ignacio Godoy        1.0          1
# 3      Emilio Calatayud        4.0          1
# 4      Inmaculada Bonet        5.0          1
# ..                  ...        ...        ...
# 495      Diana Martínez        2.0          1
# 496   Feliciana Rodrigo        4.0          1
# 497         Jenny Matas        3.0          1
# 498    Heliodoro Planas        1.0          1
# 499         Reyna Tomas        2.0          1
#
# [500 rows x 16 columns]

# %%
# Eliminamos las columnas que se han creado automáticamente con la unión de los dataframes

voluntariosf.drop(columns=["key_0", "Nombre voluntario"], inplace=True)
voluntariosf.head()
# Out:
#          Nombre  Apellidos  Nombre y Apellidos      Movil Codigo Postal  \
# 0     Feliciana     Cantón    Feliciana Cantón  620034908         39682
# 1        Amador     Llopis       Amador Llopis  665288077         27277
# 2  Jose Ignacio      Godoy  Jose Ignacio Godoy  675211243         50366
# 3        Emilio  Calatayud    Emilio Calatayud  688454142         19432
# 4    Inmaculada      Bonet    Inmaculada Bonet  668697667         41950
#
#        Pass      Perfil                              Servicios Disponibles  \
# 0  82499295       Ambos                               [Nuevas Tecnologías]
# 1  62909541       Ambos                              [Salud, El día a día]
# 2  72406087  Voluntario                [Nuevas Tecnologías, Amigos y Ocio]
# 3  55533241  Voluntario                              [Salud, El día a día]
# 4  32120399  Voluntario  [Nuevas Tecnologías, Salud, Servicios del Muni...
#
#    Status        FotoV                                                Bio  \
# 0       1   mujer1.png  Me gusta trabajar con otras personas, codo con...
# 1       0  hombre1.png  Quiero devolver a la comunidad lo que me diero...
# 2       0   mujer2.png  Me gusta pasar mi tiempo ayudando a los demás ...
# 3       1  hombre2.png  Me encanta sertirme útil y por eso estaría enc...
# 4       1   mujer1.png  Me gusta pasar mi tiempo ayudando a los demás ...
#
#   Fecha inscripcion  Estrellas  N_opinion
# 0        16/02/2021        5.0          1
# 1        15/03/2022        3.0          1
# 2        23/02/2020        1.0          1
# 3        20/01/2020        4.0          1
# 4        01/02/2022        5.0          1

# %%
voluntariosf.to_csv('voluntarios.csv')

# %% [markdown]
# ## Peticiones

# %% [markdown]
# La tabla de peticiones va a contener el asunto de las solicitudes generadas por los usuarios y el texto completo.
# Además, se va a incluir el número de kms y una fecha de creación de solicitud aleatoriamente.
#
# Creamos los asuntos y textos a partir de lo trasladado por el área de UX.

# %%
p1 = 'Me gustaría saber mandar un correo'
p2 = 'Llamar a mis nietos por el ordenador'
p3 = 'Quiero poner música en mi móvil'
p4 = 'Que no se pone el banco en el teléfono'
p5 = 'Quiero poner dibujos en el chat como mi vecina'
p6 = 'No sé qué móvil comprarme'



t1 = 'El otro día recibí un mensaje y no sé cómo responderlo por ordenador'
t2 = 'Quiero ver a mis nietos por el ordenador'
t3 = 'Me gusta un grupo de música nuevo y quiero tenerlo en el móvil'
t4 = 'Quiero consultar mi cuenta del banco por el móvil'
t5 = 'He visto que mi vecina está poniendo muñecos en el chat y también quiero'
t6 = 'Se me ha roto el móvil y quiero saber cuál comprarme'

peticiones= {p1:t1, p2:t2, p3:t3, p4:t4, p5:t5, p6:t6}

# %%
# Para crear esta tabla utilizamos un rago intermedio de la tabla de miembros.

peticionarios = miembros.iloc[171:211, 2:7:4]
peticionarios.reset_index(inplace=True)
peticionarios.drop(columns=['index'], inplace=True)
peticionarios
# Out:
#        Nombre y Apellidos   Foto miembro
# 0           Adrián Blanco  opinion5m.png
# 1       Anastasia Barrera  miembroh1.png
# 2         Teodoro Pizarro  opinion3m.png
# 3         Fabián Ferreras  miembroh1.png
# 4       Tristán Escribano  opinion2m.png
# 5      Hernando Larrañaga   opinion6.png
# 6      José Luis Gelabert   opinion6.png
# 7             Lázaro Páez  miembrom3.png
# 8             Valeria Pou  miembrom4.png
# 9    Juan Bautista Múgica  miembrom3.png
# 10           Amaro Larrea  opinion2m.png
# 11  Jose Angel Echeverría  opinion2m.png
# 12       Baldomero Ricart   opinion6.png
# 13         Ciro Carretero  miembroh3.png
# 14     Fortunato Pellicer  opinion2m.png
# 15          Iker Villegas  opinion3m.png
# 16      Jorge Quintanilla  opinion2m.png
# 17          Alfredo Soler   opinion6.png
# 18             Pili Navas  miembroh3.png
# 19           Aníbal Landa   opinion6.png
# 20       Andrea Benavente  miembrom3.png
# 21          Pelayo Arnaiz  miembroh3.png
# 22         Gabriela Jordá  opinion5m.png
# 23             Maura Seco  opinion2m.png
# 24             Coral Malo   opinion1.png
# 25           Bibiana Puga   opinion1.png
# 26       Prudencio Morata  miembrom4.png
# 27           Fausto Cases  opinion3m.png
# 28           Malena Nieto   opinion6.png
# 29             Ana Pulido  miembroh3.png
# 30         Esmeralda Real   opinion4.png
# 31     Jose Manuel Valera   opinion1.png
# 32     Marcela Cabanillas   opinion6.png
# 33        Bernarda Galván  miembroh3.png
# 34        Gabriel Benítez  miembroh3.png
# 35     Jose Luis Berrocal  miembrom4.png
# 36           Alejo Losada  miembroh3.png
# 37         Perlita Tolosa  opinion5m.png
# 38        Isidoro Naranjo   opinion4.png
# 39          Santos Arroyo  miembrom4.png

# %%
# Generamos aleatoriamente el asunto y el texto del mismo.

asunto = {'Asunto': [], 'Texto': []}

for i in np.arange(0,40):
    pt = random.choice(list(peticiones.items()))
    asunto['Asunto'].append(pt[0])
    asunto['Texto'].append(pt[1])

asunto = pd.DataFrame(asunto)

asunto.head()
# Out:
#                                            Asunto  \
# 0                 Quiero poner música en mi móvil
# 1            Llamar a mis nietos por el ordenador
# 2                       No sé qué móvil comprarme
# 3                 Quiero poner música en mi móvil
# 4  Quiero poner dibujos en el chat como mi vecina
#
#                                                Texto
# 0  Me gusta un grupo de música nuevo y quiero ten...
# 1           Quiero ver a mis nietos por el ordenador
# 2  Se me ha roto el móvil y quiero saber cuál com...
# 3  Me gusta un grupo de música nuevo y quiero ten...
# 4  He visto que mi vecina está poniendo muñecos e...

# %%
# Unimos esta nueva tabla a la principal

solicitudes = pd.concat([peticionarios, asunto], axis=1)
solicitudes.head()
# Out:
#   Nombre y Apellidos   Foto miembro  \
# 0      Adrián Blanco  opinion5m.png
# 1  Anastasia Barrera  miembroh1.png
# 2    Teodoro Pizarro  opinion3m.png
# 3    Fabián Ferreras  miembroh1.png
# 4  Tristán Escribano  opinion2m.png
#
#                                            Asunto  \
# 0                 Quiero poner música en mi móvil
# 1            Llamar a mis nietos por el ordenador
# 2                       No sé qué móvil comprarme
# 3                 Quiero poner música en mi móvil
# 4  Quiero poner dibujos en el chat como mi vecina
#
#                                                Texto
# 0  Me gusta un grupo de música nuevo y quiero ten...
# 1           Quiero ver a mis nietos por el ordenador
# 2  Se me ha roto el móvil y quiero saber cuál com...
# 3  Me gusta un grupo de música nuevo y quiero ten...
# 4  He visto que mi vecina está poniendo muñecos e...

# %%
# Generamos el rango de fechas aleatorio

creacion = {'Fecha creacion': []}

for i in np.arange(0,40):
    fech = get_random_date_between('17/6/2022', '30/7/2022')
    creacion['Fecha creacion'].append(fech)

creacion = pd.DataFrame(creacion)
solicitudes['Fecha creacion'] = creacion
solicitudes.head()
# Out:
#   Nombre y Apellidos   Foto miembro  \
# 0      Adrián Blanco  opinion5m.png
# 1  Anastasia Barrera  miembroh1.png
# 2    Teodoro Pizarro  opinion3m.png
# 3    Fabián Ferreras  miembroh1.png
# 4  Tristán Escribano  opinion2m.png
#
#                                            Asunto  \
# 0                 Quiero poner música en mi móvil
# 1            Llamar a mis nietos por el ordenador
# 2                       No sé qué móvil comprarme
# 3                 Quiero poner música en mi móvil
# 4  Quiero poner dibujos en el chat como mi vecina
#
#                                                Texto Fecha creacion
# 0  Me gusta un grupo de música nuevo y quiero ten...     04/07/2022
# 1           Quiero ver a mis nietos por el ordenador     23/06/2022
# 2  Se me ha roto el móvil y quiero saber cuál com...     28/07/2022
# 3  Me gusta un grupo de música nuevo y quiero ten...     08/07/2022
# 4  He visto que mi vecina está poniendo muñecos e...     30/06/2022

# %%
# Elegimos el rango de kms de forma aleatoria

kms = {'Kms': []}

for i in np.arange(0,40):
    km = random.randrange(5, 40)
    kms['Kms'].append(str(km)+'km')

kms = pd.DataFrame(kms)
solicitudes['Kms'] = kms
solicitudes.head()
# Out:
#   Nombre y Apellidos   Foto miembro  \
# 0      Adrián Blanco  opinion5m.png
# 1  Anastasia Barrera  miembroh1.png
# 2    Teodoro Pizarro  opinion3m.png
# 3    Fabián Ferreras  miembroh1.png
# 4  Tristán Escribano  opinion2m.png
#
#                                            Asunto  \
# 0                 Quiero poner música en mi móvil
# 1            Llamar a mis nietos por el ordenador
# 2                       No sé qué móvil comprarme
# 3                 Quiero poner música en mi móvil
# 4  Quiero poner dibujos en el chat como mi vecina
#
#                                                Texto Fecha creacion   Kms
# 0  Me gusta un grupo de música nuevo y quiero ten...     04/07/2022  33km
# 1           Quiero ver a mis nietos por el ordenador     23/06/2022  28km
# 2  Se me ha roto el móvil y quiero saber cuál com...     28/07/2022  16km
# 3  Me gusta un grupo de música nuevo y quiero ten...     08/07/2022  38km
# 4  He visto que mi vecina está poniendo muñecos e...     30/06/2022  20km

# %%
solicitudes.to_csv('solicitudes.csv')
